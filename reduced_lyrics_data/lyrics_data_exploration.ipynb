# %% [markdown]
# # Cleansing Song Lyrics Dataset
# ---
#
# ## Purpose
#
# Everyone knows that 90% of the time data scientists want to be building and fine tuning their models, but unfortunately they tend to spend 90% of their time collecting and preparing their datasets for said model instead. In light of this, we figured it would be a good idea to show off our own data cleansing skills and demonstrate the process in action using jupyter notebooks. More specifically, we are going to use this notebook to document the steps taken to prepare the lyrical dataset we will be using for training our generative Steely Dan song writing model.
#
# ---

# %% [markdown]
# ## The Data
#
# The dataset we will be using for this project is a collection of 57,650 from 643 different artists, including 88 Steely Dan songs. This dataset of songs was scraped from the website [lyricsfreak](https://www.lyricsfreak.com/) and is available at the following [Kaggle site](https://www.kaggle.com/mousehead/songlyrics), compliments of Sergey Kuznetsov who took the liberty of scraping the data and providig it publicly.
#
# The dataset is conveniantly stored in a csv file, so the first thing we want to do is load in the file using Pandas and take a look at its structure as well as a couple example records.

# %%
import pandas as pd

# Read in csv file
filename = '../songdata.csv'
dataset = pd.read_csv(filename, encoding = 'UTF-8')

# Display sample of dataset
dataset
# Out:
#              artist                   song  \
# 0              ABBA  She's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                               link  \
# 0       /a/abba/ahes+my+kind+of+girl_20598417.html
# 1            /a/abba/andante+andante_20002708.html
# 2             /a/abba/as+good+as+new_20003033.html
# 3                       /a/abba/bang_20598415.html
# 4           /a/abba/bang+a+boomerang_20002668.html
# ...                                            ...
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# 57646  /z/ziggy+marley/hand+to+mouth_20531167.html
# 57647           /z/zwan/come+with+me_20148981.html
# 57648                 /z/zwan/desire_20148986.html
# 57649              /z/zwan/heartsong_20148991.html
#
#                                                     text
# 0      Look at her face, it's a wonderful face  \nAnd...
# 1      Take it easy with me, please  \nTouch me gentl...
# 2      I'll never know why I had to go  \nWhy I had t...
# 3      Making somebody happy is a question of give an...
# 4      Making somebody happy is a question of give an...
# ...                                                  ...
# 57645  Irie days come on play  \nLet the angels fly l...
# 57646  Power to the workers  \nMore power  \nPower to...
# 57647  all you need  \nis something i'll believe  \nf...
# 57648  northern star  \nam i frightened  \nwhere can ...
# 57649  come in  \nmake yourself at home  \ni'm a bit ...
#
# [57650 rows x 4 columns]

# %% [markdown]
# From the above we see that our dataset includes 57,650 songs as previously mentioned and for each song record we have 4 fields:
#
#     1) artist: name of the artist the song belongs to
#     2) song: title of the song
#     3) link: subpage of https://www.lyricsfreak.com/ from which the song was pulled
#     4) text: single string value of all the lyrics for the song
#
# We wont be using the link field for our purposes, so lets go ahead and delete this column. After doing so, lets then print some more information and statistics on our remaining 3 columns. The statistics might not be too useful since these are all string fields, but it is generally good practice to do this to get a feel for the scope of the data in each column.

# %%
# delete "link" field
dataset = dataset.drop(columns = ['link'], axis = 1)

# display some useful statistics
dataset.info()
dataset.describe(include = 'all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57650 entries, 0 to 57649
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   artist  57650 non-null  object
#  1   song    57650 non-null  object
#  2   text    57650 non-null  object
# dtypes: object(3)
# memory usage: 1.3+ MB
#               artist                                    song  \
# count          57650                                   57650
# unique           643                                   44824
# top     Donna Summer  Have Yourself A Merry Little Christmas
# freq             191                                      35
#
#                                                      text
# count                                               57650
# unique                                              57494
# top     Chestnuts roasting on an open fire  \nJack Fro...
# freq                                                    6

# %% [markdown]
# Above we can see that our dataset no longer has the "link" column. It is worth noting from the displayed info that the remaining columns contain no Null values. This means all records have a value in each of the three fields and is nice since we generally would need to handle Null values either by filling in the information, removing the records, or just being aware of their existance.
#
# In the lower table we have some information on the number of unique values for each field and the most frequent values. For the artists we confirm the dataset contains songs from 643 unique artists, with the most prolific being Donna Summer. Additionally, we see that not all of our songs are unique. There is a significant amount of overlap in the song titles, with 12,826 duplicates, and a small overlap in the exact lyrics to these songs, with 156 duplicates. This will be the first issue we need to address when cleansing and preparing our data.

# %% [markdown]
# ## Data Cleansing
#
# Before we even think about working with the data and reformatting it for our models, we first need to validate the integrity of the dataset and the values within it. Typically this usually involves removing duplicate records, handling Null values, changing datatypes, and altering incorrect information. Thankfully for this dataset all three fields are Null free and in the format we want, string format. So in the section to follow we will focus on removing the duplicates songs, and handling extraneous issues with our song lyrics.
#
# ### 1) Removing Duplicates
#
# As mentioned already, our dataset has a number of duplicate song records. We don't want any songs to be over represented in our dataset, so we are going to need to identify all the duplicates and decide which version to keep.
#
# Our initial instinct might be to simply remove all the songs with the same title, but it turns out that completely different songs sometimes just have the same name. As an example, below are two records each with the song title "Movin' Out", one by Aerosmith and the other by Billy Joel. As can we see, the lyrics for each are completely different and the two are distinct songs despite having the same name.

# %%
# Displaying songs titled "Movin' Out"
dataset[dataset['song'] == "Movin' Out"]
# Out:
#           artist        song  \
# 169    Aerosmith  Movin' Out
# 1410  Billy Joel  Movin' Out
#
#                                                    text
# 169   We all live on the edge of town  \nWhere we al...
# 1410  Anthony works in the grocery store  \nSavin hi...

# %%
# Printing some more of the songs
movin_out_songs = dataset[dataset['song'] == "Movin' Out"]

print('Artist: ' + movin_out_songs.iloc[0]['artist'])
print('Title: ' + movin_out_songs.iloc[0]['song'])
print(movin_out_songs.iloc[0]['text'][:236])
print('\n')
print('Artist: ' + movin_out_songs.iloc[1]['artist'])
print('Title: ' + movin_out_songs.iloc[1]['song'])
print(movin_out_songs.iloc[1]['text'][:330])
# Out:
# Artist: Aerosmith
# Title: Movin' Out
# We all live on the edge of town
# Where we all live ain't a soul around
# People start a-comin'
# All we do is just a-grin
# Said we gotta move out
# 'Cause the city's movin' in
# I said we gotta move out
# 'Cause the city's movin' in
#
#
# Artist: Billy Joel
# Title: Movin' Out
# Anthony works in the grocery store
# Savin his pennies for some day
# Mama Leone left a note on the door
# She said "Sonny move out to the country"
# Ah but working too hard can give you
# A heart attack, ack, ack, ack, ack, ack
# You ought-a know by now
# Who needs a house out in Hackensack?
# Is that all you get for your money

# %% [markdown]
# This shows that not all songs with the same title are necessarily duplicates, and that we should probably focus on the text in each song to determine if they are the same. Obviously songs that have the exact same text should be considered duplicates, like the 6 copies of "My Girl" shown above (the ones that start with "I've got sunshine on a cloudy day \nWhen it's..."). However, what about songs where only a few words or characters have been changed? For instance, below are two records of the song "Have Yourself A Merry Little Christmas", one by America and the other by Barbra Streisand. These are clearly the same song, but with slightly different formattings and where Barbra Streisand's version includes an intro.

# %%
# Grab all songs with title "Have Yourself A Merry Little Christmas"
merry_christmas_songs = dataset[dataset['song'] == "Have Yourself A Merry Little Christmas"]

# Show Two Examples With Slightly Different Lyrics
print('Artist: ' + merry_christmas_songs.iloc[0]['artist'])
print('Title: ' + merry_christmas_songs.iloc[0]['song'])
print(merry_christmas_songs.iloc[0]['text'][:226])
print('\n')
print('Artist: ' + merry_christmas_songs.iloc[1]['artist'])
print('Title: ' + merry_christmas_songs.iloc[1]['song'])
print(merry_christmas_songs.iloc[1]['text'][:350])
# Out:
# Artist: America
# Title: Have Yourself A Merry Little Christmas
# Have yourself a Merry Little Christmas
# Let your heart be light
# From now on our troubles will be out of sight
#
# Have yourself a Merry Little Christmas
# Make the Yuletide gay
# From now on our troubles will be miles away
#
#
# Artist: Barbra Streisand
# Title: Have Yourself A Merry Little Christmas
# Christmas' future is far away
# Christmas' past is passed
# Christmas' present is here today
# Bringing joy that will last
# Have yourself a merry little Christmas
# Let your hearts be light
# From now on our troubles will be out of sight
# Have yourself a merry little Christmas
# Make the Yule time gay
# From now on our troubles will be miles away

# %% [markdown]
# To capture instances like this, where the songs are essentially the same but with a few changes, we are going to use the python library fuzzywuzzy. This library has a useful function called fuzzy match that tells us how similar two strings are. More specifically, it calculates how similar two strings are using the [Levenshtein distance](https://en.wikipedia.org/wiki/Levenshtein_distance) between the two strings, which is a measure of how many changes need to be made to make the strings exactly the same. Additionally, the fuzzywuzzy library has additional functions that preprocess the strings for us to improve the comparison. Below we test several of these functions on the two "Movin' Out" songs and the two "Have Yourself A Merry Little Christmas" songs from earlier. Note we convert all text to lowercase for the functions that don't implicitly do so.

# %%
from fuzzywuzzy import fuzz

# Get text for each song
movin_out_1 = movin_out_songs.iloc[0]['text'].lower()
movin_out_2 = movin_out_songs.iloc[1]['text'].lower()
merry_christmas_1 = merry_christmas_songs.iloc[0]['text'].lower()
merry_christmas_2 = merry_christmas_songs.iloc[1]['text'].lower()

# Calculate fuzzy match values
print("Movin' Out fuzzy match ratio: ", fuzz.ratio(movin_out_1, movin_out_2))
print("Movin' Out fuzzy match partial ratio: ", fuzz.partial_ratio(movin_out_1, movin_out_2))
print("Movin' Out fuzzy match token sort ratio: ", fuzz.token_sort_ratio(movin_out_1, movin_out_2))
print("Movin' Out fuzzy match token set ratio: ", fuzz.token_set_ratio(movin_out_1, movin_out_2))
print('\n')
print("Merry Little Christmas fuzzy match ratio: ", fuzz.ratio(merry_christmas_1, merry_christmas_2))
print("Merry Little Christmas fuzzy match partial ratio: ", fuzz.partial_ratio(merry_christmas_1, merry_christmas_2))
print("Merry Little Christmas fuzzy match token sort ratio: ", fuzz.token_sort_ratio(merry_christmas_1, merry_christmas_2))
print("Merry Little Christmas fuzzy match token set ratio: ", fuzz.token_set_ratio(merry_christmas_1, merry_christmas_2))
# Out:
# Movin' Out fuzzy match ratio:  42
# Movin' Out fuzzy match partial ratio:  45
# Movin' Out fuzzy match token sort ratio:  52
# Movin' Out fuzzy match token set ratio:  58
#
#
# Merry Little Christmas fuzzy match ratio:  73
# Merry Little Christmas fuzzy match partial ratio:  76
# Merry Little Christmas fuzzy match token sort ratio:  82
# Merry Little Christmas fuzzy match token set ratio:  95

# %% [markdown]
# In general, the fuzzy match ratio increases if the two strings are more similar. The different functions process the strings differently (Ex. reordering words alphabetically, etc.) , hence why the ratios are different for each function. Ideally, we would calculate these ratios between each combination of songs in our dataset, but that would be extremely computationally intensive and take years for my pathetic PC to process. Instead, we will assume that songs with different titles are 100% not the same song, so then we only need to calculate these values between songs with the same title.
#
# To help us compare the songs with the same title we will use the built in "extractOne" function from the fuzzywuzzy library. This function lets us find the maximum match between one string and a list of strings. We can use this function to more efficiently compare the lyrics from songs with the same name. Below we wrote a function that does just that and tested it on the set of all "Have Yourself A Merry Little Christmas" songs.

# %%
from fuzzywuzzy import process

def fuzzyCompare(data_subset):
    '''
    Takes a subset of our dataset and creates a new column with the highest fuzzy match ratio
    between this song and all other songs in the subset.
    '''
    # Initialize list of values for fuzzy match
    fuzzy_match = [[],[],[],[]]
    
    # Iterate over songs to find highest fuzzy match between the song and the rest of the dataset
    for i in range(len(data_subset)):
        row_number = data_subset.index[i]
        title = data_subset.iloc[i]['text']
        other_titles = list(data_subset.drop(row_number)['text'])
        ratio_1 = process.extractOne(title, other_titles, str.lower, fuzz.ratio)[1]
        ratio_2 = process.extractOne(title, other_titles, str.lower, fuzz.partial_ratio)[1]
        ratio_3 = process.extractOne(title, other_titles, str.lower, fuzz.token_sort_ratio)[1]
        ratio_4 = process.extractOne(title, other_titles, str.lower, fuzz.token_set_ratio)[1]
        fuzzy_match[0].append(ratio_1)
        fuzzy_match[1].append(ratio_2)
        fuzzy_match[2].append(ratio_3)
        fuzzy_match[3].append(ratio_4)
    
    # Add ratios to dataframe
    data_subset.insert(3, 'max_fm_ratio', fuzzy_match[0])
    data_subset.insert(4, 'max_fm_partial_ratio', fuzzy_match[1])
    data_subset.insert(5, 'max_fm_token_sort_ratio', fuzzy_match[2])
    data_subset.insert(6, 'max_fm_token_set_ratio', fuzzy_match[3])
        
    return data_subset

# Test function
fuzzy_test = fuzzyCompare(merry_christmas_songs.copy())

# Display results
fuzzy_test.sort_values(['max_fm_ratio','max_fm_partial_ratio','max_fm_token_sort_ratio','max_fm_token_set_ratio'])
# Out:
#                    artist                                    song  \
# 9072         James Taylor  Have Yourself A Merry Little Christmas
# 25838           Bob Dylan  Have Yourself A Merry Little Christmas
# 1077     Barbra Streisand  Have Yourself A Merry Little Christmas
# 3222        Cliff Richard  Have Yourself A Merry Little Christmas
# 31083      Ellie Goulding  Have Yourself A Merry Little Christmas
# 40250           Kim Wilde  Have Yourself A Merry Little Christmas
# 32613       Fifth Harmony  Have Yourself A Merry Little Christmas
# 47895          Perry Como  Have Yourself A Merry Little Christmas
# 43581      Michael Bolton  Have Yourself A Merry Little Christmas
# 43662       Michael Buble  Have Yourself A Merry Little Christmas
# 27822     Christmas Songs  Have Yourself A Merry Little Christmas
# 4495            Doris Day  Have Yourself A Merry Little Christmas
# 11614      Linda Ronstadt  Have Yourself A Merry Little Christmas
# 45254        Neil Diamond  Have Yourself A Merry Little Christmas
# 2227           Carpenters  Have Yourself A Merry Little Christmas
# 11273         Leann Rimes  Have Yourself A Merry Little Christmas
# 28177            Coldplay  Have Yourself A Merry Little Christmas
# 1310         Bette Midler  Have Yourself A Merry Little Christmas
# 2620              Chicago  Have Yourself A Merry Little Christmas
# 9967         Judy Garland  Have Yourself A Merry Little Christmas
# 31028     Ella Fitzgerald  Have Yourself A Merry Little Christmas
# 39973       Kenny Loggins  Have Yourself A Merry Little Christmas
# 661               America  Have Yourself A Merry Little Christmas
# 2888   Christina Aguilera  Have Yourself A Merry Little Christmas
# 4068          Demi Lovato  Have Yourself A Merry Little Christmas
# 11732       Lionel Richie  Have Yourself A Merry Little Christmas
# 12217     Luther Vandross  Have Yourself A Merry Little Christmas
# 16313          Pretenders  Have Yourself A Merry Little Christmas
# 23978           Amy Grant  Have Yourself A Merry Little Christmas
# 24103       Andy Williams  Have Yourself A Merry Little Christmas
# 25370          Billy Joel  Have Yourself A Merry Little Christmas
# 26776         Carly Simon  Have Yourself A Merry Little Christmas
# 38000         John Denver  Have Yourself A Merry Little Christmas
# 40050        Kenny Rogers  Have Yourself A Merry Little Christmas
# 51268           Sam Smith  Have Yourself A Merry Little Christmas
#
#                                                     text  max_fm_ratio  \
# 9072   (Hugh Martin and Ralph Blane)  \n  \nChristmas...            81
# 25838  Have yourself  \nA merry little Christmas  \nL...            83
# 1077   Christmas' future is far away  \nChristmas' pa...            84
# 3222   Have yourself a merry little Christmas,  \nLet...            85
# 31083  Have yourself a merry little Christmas  \nLet ...            91
# 40250  Have yourself a merry little Christmas  \nLet ...            91
# 32613  [Camila:]  \nHave yourself a Merry Little Chri...            92
# 47895  Have yourself a merry little Christmas  \nLet ...            93
# 43581  Have yourself a merry little Christmas  \nLet ...            93
# 43662  Have yourself a merry little Christmas  \nLet ...            93
# 27822  (From the film Meet Me In St. Louis - Hugh Mar...            93
# 4495   Have yourself a merry little Christmas  \nLet ...            94
# 11614  Have yourself a merry little Christmas.  \nLet...            94
# 45254  Christmas future is far away  \nChristmas past...            98
# 2227   Christmas future is far away  \nChristmas past...            98
# 11273  Have yourself a merry little Christmas  \nLet ...            99
# 28177  Have yourself a merry little Christmas  \nLet ...            99
# 1310   Have yourself a merry little Christmas,  \nLet...            99
# 2620   Have yourself a merry little Christmas,  \nLet...            99
# 9967   Have yourself a merry little Christmas  \nLet ...           100
# 31028  Have yourself a merry little christmas  \nLet ...           100
# 39973  Have yourself a merry little christmas  \nLet ...           100
# 661    Have yourself a Merry Little Christmas  \nLet ...           100
# 2888   Have yourself a merry little Christmas  \nLet ...           100
# 4068   Oh yeah, mmm  \nHave yourself a merry little C...           100
# 11732  Have yourself  \nA merry little Christmas  \nL...           100
# 12217  Have yourself a merry little Christmas  \nLet ...           100
# 16313  Have yourself  \nA merry little Christmas  \nL...           100
# 23978  Have yourself a Merry little Christmas  \nLet ...           100
# 24103  Have yourself a merry little Christmas  \nLet ...           100
# 25370  Have yourself  \nA merry little Christmas  \nL...           100
# 26776  Have yourself a Merry little Christmas  \nLet ...           100
# 38000  Have yourself a merry little Christmas  \nLet ...           100
# 40050  Have yourself a merry little Christmas  \nLet ...           100
# 51268  Oh yeah, mmm  \nHave yourself a merry little C...           100
#
#        max_fm_partial_ratio  max_fm_token_sort_ratio  max_fm_token_set_ratio
# 9072                     88                       84                      96
# 25838                    92                       88                      98
# 1077                     95                       87                      97
# 3222                     96                       86                      99
# 31083                    91                       90                      97
# 40250                   100                       92                     100
# 32613                    90                       95                     100
# 47895                    92                       91                      99
# 43581                    96                       95                     100
# 43662                    98                       94                     100
# 27822                   100                       94                     100
# 4495                     98                       93                      97
# 11614                    98                       94                      99
# 45254                    98                      100                     100
# 2227                    100                      100                     100
# 11273                    99                       99                     100
# 28177                    99                       99                     100
# 1310                     99                      100                     100
# 2620                    100                      100                     100
# 9967                     99                       99                      99
# 31028                    99                       99                      99
# 39973                    99                      100                     100
# 661                     100                      100                     100
# 2888                    100                      100                     100
# 4068                    100                      100                     100
# 11732                   100                      100                     100
# 12217                   100                      100                     100
# 16313                   100                      100                     100
# 23978                   100                      100                     100
# 24103                   100                      100                     100
# 25370                   100                      100                     100
# 26776                   100                      100                     100
# 38000                   100                      100                     100
# 40050                   100                      100                     100
# 51268                   100                      100                     100

# %% [markdown]
# Judging from the above test on the set of "Have Yourself A Merry Little Christmas" songs, it appears that the "token set ratio" fuzzy match function is the most consistent. Since all 36 versions of this song are essentially the same and should be removed, we want to use the function that returns high values for these songs. The "token set ratio" function does this best in this regard with all value > 95.
#
# Now lets check the performance of the functions on a set of randomly chosen, and completely unrelated songs.

# %%
import numpy as np

# choose random song indices
n = len(dataset)
random_indxs = np.random.choice(n, 50, replace = False)

# grab songs
random_songs = dataset.iloc[random_indxs]

# fuzzy match songs
fuzzy_test = fuzzyCompare(random_songs.copy())

# Display results
fuzzy_test.sort_values(['max_fm_ratio','max_fm_partial_ratio','max_fm_token_sort_ratio','max_fm_token_set_ratio'])
# Out:
#                      artist                           song  \
# 53140           Tim Buckley              Goodbye And Hello
# 1015                 Barbie       It's A Perfect Christmas
# 5373           Eric Clapton   Highway 49 - With Jimmy Page
# 2550                   Cher              Girl From Ipanema
# 3438          Conway Twitty     Don't Mess Up A Good Thing
# 47668            Paul Simon                      Beautiful
# 12344          Mariah Carey                        Bye Bye
# 21654          Wishbone Ash      The Day I Found Your Love
# 34043                  Glee                    Don't Speak
# 18913         Stevie Wonder            I Wanna Talk To You
# 50743        Reo Speedwagon            They're On The Road
# 27642             Chris Rea                 Stainsby Girls
# 30236       Doobie Brothers                  Carry Me Away
# 24133         Andy Williams             My Favorite Things
# 44181               Misfits                   The Haunting
# 48291      Phineas And Ferb                Thank You Santa
# 4694          Eddie Cochran              Mean When I'm Mad
# 5141         Emmylou Harris   Never Be Anyone Else But You
# 51723                Slayer                Spill The Blood
# 26571     Bruce Springsteen                     Goin' Cali
# 47403           Patsy Cline                     Come On In
# 34014                  Glee                      Barracuda
# 36370            Ian Hunter  Just The Way You Look Tonight
# 54457               Unknown           Pop! Goes The Weasel
# 36316          Human League             Heart Like A Wheel
# 32416         Faith No More               The Last To Know
# 341              Air Supply                         Tonite
# 35375                Hanson                     Dream Girl
# 55034      Vertical Horizon          Welcome To The Bottom
# 20296                 Usher                Can You Help Me
# 50906               Rihanna            Why Am I So In Love
# 14729             Offspring            Race Against Myself
# 8435           Indigo Girls                     Drift Away
# 20889        Violent Femmes                   Good Feeling
# 21500                   Who                  The Quiet One
# 57282      Yngwie Malmsteen       All I Want Is Everything
# 23728  Allman Brothers Band             She Has Funny Cars
# 23952             Amy Grant                Come Be With Me
# 13247           The Monkees    We Were Made For Each Other
# 51229                  Rush                       Slipping
# 22359        Zac Brown Band                           Mary
# 18441               Santana              Black Magic Woman
# 27006           Cat Stevens                        Trouble
# 36665               Incubus                         Follow
# 21766            X-Ray Spex            I Can't Do Anything
# 43637         Michael Buble                      All Of Me
# 56916                Xscape                    Let Me Know
# 33781        George Michael                 Kissing A Fool
# 43354            Mazzy Star                     Ride It On
# 20948         Vonda Shepard                Someone You Use
#
#                                                     text  max_fm_ratio  \
# 53140  The antique people are down in the dungeons  \...            44
# 1015   Well I've been waiting all year  \nJust for th...            44
# 5373   Well, I'm gonna get up in the morning  \nHit t...            45
# 2550   Tall and tan and young and lovely  \nThe girl ...            45
# 3438   Good thing, good thing, good thing, good thing...            45
# 47668  Snowman sittin' in the sun doesn't have time t...            45
# 12344  This is for my peoples who just lost somebody,...            45
# 21654  When I was a stranger to you in the night  \nA...            45
# 34043  You and me  \nWe used to be together  \nEveryd...            45
# 18913  M-m-m-m-m-m-m-m-m-m-m-m-m-m-m  \nLord, Lordy, ...            45
# 50743  It's the season of the golden leaves  \nWhen t...            46
# 27642  Some girls used to kiss and run  \nNever knew ...            46
# 30236  There was a place in East St. Louis, it was in...            46
# 24133  Raindrops on roses and whiskers on kittens  \n...            46
# 44181  The darkness bleeds violent sights  \nIt purge...            46
# 48291  Christmas morning, so much fun.  \nDown the st...            46
# 4694   You petrify me, a-baby, ooh, satisfy me, a-bab...            46
# 5141   There'll never be anyone else but you for me  ...            46
# 51723  Come walk with me through endless time.  \nSee...            46
# 26571  Well he'd been hearing too many voices and fee...            46
# 47403  Come on in and sit right down and make yoursel...            46
# 34014  So this ain't the end, I saw you again today  ...            46
# 36370  I fell in love with a working girl  \nWe both ...            46
# 54457    \n  \n'Round and 'round the cobbler's bench ...            46
# 36316  Calling up the promised land  \nJohnny Seven's...            46
# 32416  Where it grows on trees  \nBut never blooms  \...            46
# 341    Now you tell me that the time is right  \nYou'...            46
# 35375  Tell me that you love me  \nYou say you don't ...            46
# 55034  Welcome home its been a while  \nWe've been ex...            46
# 20296  Living on the edge out of control  \nAnd the w...            46
# 50906  Chris Brown:  \nYou know what I'm thinkin'  \n...            47
# 14729  All I want  \nAll I need  \nAlways lies just o...            47
# 8435   Day after day I'm more confused  \nStill I loo...            47
# 20889  Good feeling  \nWon't you stay with me just a ...            47
# 21500  [Chorus]  \nEverybody calls me the quiet one  ...            47
# 57282  Before my eyes the world is falling  \nBut thr...            47
# 23728  Every day I try so hard to know your mind  \nA...            47
# 23952  Baby this life can break your heart  \nEveryon...            47
# 13247  By Carole Bayer and George Fischoff  \nI wante...            47
# 51229  Meant to tell you  \nTell you from the start  ...            47
# 22359  Mary, Mary, why you want to do me this way?  \...            47
# 18441  Got a Black Magic Woman  \nGot a Black Magic W...            47
# 27006  Trouble  \nOh trouble set me free  \nI have se...            47
# 36665  Look at you  \nWith all your shiny  \nToys for...            47
# 21766  I can't write  \nAnd I can't sing  \nI can't d...            47
# 43637  All of me why not take all of me  \nCan't you ...            47
# 56916  I got something for you,  \nAnd I think you're...            48
# 33781  You are far,  \nWhen I could have been your st...            48
# 43354  Ride it on baby,  \nInto my view  \nRide it on...            48
# 20948  Just a shoulder to cry on  \nThat's all I've b...            48
#
#        max_fm_partial_ratio  max_fm_token_sort_ratio  max_fm_token_set_ratio
# 53140                    47                       54                      60
# 1015                     47                       57                      62
# 5373                     46                       52                      63
# 2550                     46                       54                      60
# 3438                     46                       57                      63
# 47668                    46                       58                      58
# 12344                    48                       58                      66
# 21654                    49                       57                      60
# 34043                    50                       57                      63
# 18913                    50                       61                      66
# 50743                    46                       58                      63
# 27642                    47                       53                      62
# 30236                    47                       54                      61
# 24133                    47                       55                      54
# 44181                    47                       56                      54
# 48291                    47                       56                      60
# 4694                     47                       57                      61
# 5141                     47                       57                      67
# 51723                    47                       58                      60
# 26571                    47                       59                      60
# 47403                    47                       59                      62
# 34014                    47                       60                      62
# 36370                    48                       57                      61
# 54457                    48                       57                      62
# 36316                    48                       57                      62
# 32416                    48                       58                      62
# 341                      48                       58                      68
# 35375                    48                       59                      67
# 55034                    49                       55                      62
# 20296                    49                       61                      68
# 50906                    47                       61                      63
# 14729                    48                       53                      57
# 8435                     48                       55                      61
# 20889                    48                       57                      70
# 21500                    48                       59                      62
# 57282                    48                       61                      64
# 23728                    48                       61                      64
# 23952                    48                       61                      64
# 13247                    49                       56                      60
# 51229                    49                       56                      60
# 22359                    49                       57                      64
# 18441                    49                       57                      67
# 27006                    49                       58                      63
# 36665                    50                       50                      56
# 21766                    50                       52                      56
# 43637                    50                       58                      68
# 56916                    49                       62                      64
# 33781                    49                       62                      67
# 43354                    50                       58                      70
# 20948                    50                       59                      63

# %% [markdown]
# Judging from above, it appears that all 4 of the different fuzzy match functions do a good job of returning low values for different songs. Though the "token set ratio" function returns pretty high values in this case, they are still distinguishably lower than when the songs are similar. As such, I am still leaning towards using this function over the others, possibly with a cutoff value of 90 for matches.
#
# Just to be sure, let's test each function one more time on a set of songs that have similar lyrics and word choices, but are not the same songs. I feel a good test for this is to use just Beatles songs, since roughly half of their songs are about love in some shape or manner.

# %%
# grab beatles songs
bealtes_songs = dataset[dataset['artist'] == "The Beatles"]

# choose random songs
n = len(bealtes_songs)
random_indxs = np.random.choice(n, 50, replace = False)
random_beatles_songs = bealtes_songs.iloc[random_indxs]

# fuzzy match songs
fuzzy_test = fuzzyCompare(random_beatles_songs.copy())

# Display results
fuzzy_test.sort_values(['max_fm_ratio','max_fm_partial_ratio','max_fm_token_sort_ratio','max_fm_token_set_ratio'])
# Out:
#             artist                              song  \
# 24712  The Beatles                      Commonwealth
# 1220   The Beatles               Give Peace A Chance
# 24749  The Beatles                          Hey Jude
# 24713  The Beatles                  Crinsk Dee Night
# 24759  The Beatles                         I Me Mine
# 24804  The Beatles                     Los Paranoias
# 24714  The Beatles                      Cry Baby Cry
# 24819  The Beatles                     Mrs. Robinson
# 24797  The Beatles       Keep Your Hands Off My Baby
# 24814  The Beatles                  Mean Mr. Mustard
# 24799  The Beatles                      Lady Madonna
# 24742  The Beatles                        Good Night
# 24801  The Beatles                         Let It Be
# 24822  The Beatles                    Norwegian Wood
# 1223   The Beatles                             Help!
# 24774  The Beatles                  I'll Cry Instead
# 1228   The Beatles                           Lucille
# 24709  The Beatles                       Cold Turkey
# 24800  The Beatles                 Lend Me Your Comb
# 24825  The Beatles                   Nothin' Shakin'
# 24769  The Beatles       If I Needed Someone To Love
# 24739  The Beatles                   Golden Slumbers
# 24750  The Beatles                     Hold Me Tight
# 24778  The Beatles  I'm Gonna Sit Right Down And Cry
# 24813  The Beatles                          Matchbox
# 24812  The Beatles                   Martha, My Dear
# 24738  The Beatles                       Glass Onion
# 24828  The Beatles                  Octopus's Garden
# 24736  The Beatles                              Girl
# 24746  The Beatles                Hello, Little Girl
# 24757  The Beatles                       I Feel Fine
# 1224   The Beatles                    Helter Skelter
# 24694  The Beatles                  All Together Now
# 24758  The Beatles             I Got To Find My Baby
# 24732  The Beatles                      For You Blue
# 24787  The Beatles                 It's All Too Much
# 24776  The Beatles                       I'm A Loser
# 1200   The Beatles                All I've Got To Do
# 24767  The Beatles                         If I Fell
# 1218   The Beatles                        For No One
# 24821  The Beatles                          No Reply
# 24734  The Beatles                    From Me To You
# 1201   The Beatles                    And I Love Her
# 24805  The Beatles                        Love Me Do
# 24726  The Beatles                     Eleanor Rigby
# 1226   The Beatles             Leave My Kitten Alone
# 24829  The Beatles                       Oh! Darling
# 24720  The Beatles                   Don't Bother Me
# 24806  The Beatles                 Love Of The Loved
# 24722  The Beatles                 Don't Let Me Down
#
#                                                     text  max_fm_ratio  \
# 24712  Immigrants. Wilson Health said to the immgrant...            43
# 1220   Two, one two three four  \nEverybody's talking...            43
# 24749  Hey Jude, don't make it bad  \nTake a sad song...            43
# 24713  [Speech]  \n  \nBrian Matthew: The next few mi...            44
# 24759  All through' the day  \nI me mine, I me mine, ...            44
# 24804  Joe Praries and the prarie walliflowers  \nLos...            44
# 24714  Cry baby cry  \nMake your mother sigh  \nShe's...            45
# 24819  and here's to you Mrs. Robinson  \njesus loves...            45
# 24797  We've been friends for oh, so long  \nI let yo...            45
# 24814  Mean Mister Mustard sleeps in the park  \nShav...            45
# 24799  Lady Madonna, children at your feet  \nWonder ...            46
# 24742  Now it's time to say good night  \nGood night ...            46
# 24801  When I find myself in times of trouble, Mother...            46
# 24822  I once had a girl, or should I say, she once h...            46
# 1223   Help!  \nHelp! I need somebody,  \nHelp! Not j...            46
# 24774  I've got every reason on earth to be mad  \n'C...            46
# 1228   Ah Lucille  \nBaby do your sister's will  \nAh...            46
# 24709  Temperature's rising  \nFever is high  \nCan't...            46
# 24800  Lend me your comb  \nIt's time to go home  \nI...            46
# 24825  I tried to find out  \nWhat love is all about,...            46
# 24769  If I needed someone to love  \nYoure the woman...            46
# 24739  Once there was a way,  \nTo get back homeward....            47
# 24750  It feels so right now, hold me tight,  \nTell ...            47
# 24778  I'm gonna sit right down and cry over you  \nI...            47
# 24813  I said I'm sitting here watching  \nMatchbox h...            47
# 24812  Martha, my dear  \nThough I spend my days in c...            47
# 24738  I told you about strawberry fields  \nYou know...            47
# 24828  I'd like to be under the sea  \nIn an octopus'...            47
# 24736  Is there anybody going to listen to my story  ...            47
# 24746  Hello little girl  \nHello little girl  \nHell...            47
# 24757  Baby's good to me, you know,  \nShe's happy as...            47
# 1224   When I get to the bottom I go back to the top ...            47
# 24694  One two three four  \nCan I have a little more...            47
# 24758  (Berry)  \n  \nI'm gonna search this town  \nF...            48
# 24732  Because you're sweet and lovely, girl, I love ...            48
# 24787  It's all too much, It's all too much  \n  \nWh...            48
# 24776  I'm a loser  \nI'm a loser  \nAnd I'm not what...            48
# 1200   Whenever I want you around, yeah  \nAll I gott...            48
# 24767  If I fell in love with you  \nWould you promis...            48
# 1218   Your day breaks, your mind aches  \nYou find t...            48
# 24821  This happened once before  \nWhen I came to yo...            48
# 24734  Da da da, da da dumb dumb da  \nDa da da, da d...            48
# 1201   I give her all my love  \nThat's all I do  \nA...            48
# 24805  Love, love me do.  \nYou know I love you,  \nI...            48
# 24726  Ah look at all the lonely people  \nAh look at...            49
# 1226   You better leave my kitten all alone,  \nYou b...            49
# 24829  Oh! Darling, please believe me  \nI'll never d...            49
# 24720  Since she's been gone I want no one to talk to...            49
# 24806  Each time I look into your eyes  \nI see that ...            49
# 24722  Don't let me down  \nDon't let me down  \nDon'...            49
#
#        max_fm_partial_ratio  max_fm_token_sort_ratio  max_fm_token_set_ratio
# 24712                    44                       48                      56
# 1220                     46                       49                      52
# 24749                    47                       47                      63
# 24713                    46                       52                      61
# 24759                    46                       53                      60
# 24804                    47                       51                      62
# 24714                    46                       53                      55
# 24819                    46                       53                      60
# 24797                    46                       58                      65
# 24814                    48                       50                      55
# 24799                    46                       54                      58
# 24742                    47                       49                      57
# 24801                    47                       56                      58
# 24822                    47                       56                      60
# 1223                     47                       58                      74
# 24774                    47                       59                      65
# 1228                     48                       52                      60
# 24709                    48                       55                      59
# 24800                    48                       56                      60
# 24825                    49                       52                      64
# 24769                    49                       58                      63
# 24739                    47                       51                      55
# 24750                    48                       54                      65
# 24778                    48                       55                      56
# 24813                    48                       56                      65
# 24812                    48                       57                      64
# 24738                    48                       58                      61
# 24828                    48                       59                      63
# 24736                    48                       59                      64
# 24746                    48                       59                      65
# 24757                    48                       60                      61
# 1224                     48                       62                      64
# 24694                    49                       51                      58
# 24758                    48                       58                      65
# 24732                    48                       63                      61
# 24787                    49                       59                      64
# 24776                    49                       61                      62
# 1200                     49                       61                      62
# 24767                    49                       63                      67
# 1218                     50                       60                      64
# 24821                    50                       60                      65
# 24734                    50                       61                      63
# 1201                     51                       59                      63
# 24805                    52                       54                      74
# 24726                    49                       53                      59
# 1226                     49                       58                      59
# 24829                    49                       58                      60
# 24720                    49                       62                      65
# 24806                    51                       61                      65
# 24722                    52                       56                      60

# %% [markdown]
# Looks like my Beatles theory either doesn't hold up or these functions distinguish between them pretty well even though the concepts and vocabulary between the songs may be similar. As such, moving forward lets use the token set ratio fuzzy match function to determine if different records are the same song. And let's consider anysong with a value >= 90 to be a duplicate.
#
# With our new rule in place, lets re-define our function for calculating the fuzzy match values using only the token set ratio function.

# %%
# Re-define our fuzzyCompare function to only perform token_set_ratio fuzzy compare
def fuzzyCompare(data_subset):
    '''
    Takes a subset of our dataset and creates a new column with the highest fuzzy match ratio
    between this song and all other songs in the subset.
    '''
    # Initialize list of values for fuzzy match
    fuzzy_match = []
    
    # Iterate over songs to find highest fuzzy match between the song and the rest of the dataset
    for i in range(len(data_subset)):
        row_number = data_subset.index[i]
        title = data_subset.iloc[i]['text']
        other_titles = list(data_subset.drop(row_number)['text'])
        ratio = process.extractOne(title, other_titles, str.lower, fuzz.token_set_ratio)[1]
        fuzzy_match.append(ratio)
    
    # Add ratios to dataframe
    data_subset.insert(3, 'max_fuzzy_match', fuzzy_match)
        
    return data_subset

# %% [markdown]
# Now lets use the above function to actually remove duplicates from our dataset. To do so, lets first build a wrapper function that identifies all sets of duplicated song titles, calculates the fuzzy match rates for each using th above function, and using these values picks the unique songs. For clarity, we remind the user that a duplicate song will be considered a song which has a fuzzy match value >= 90 with another song of the same name already in our dataset.

# %%
import string

# function that removes all records with duplicate song titles from dataset
def DedupeDataset(data, fuzzy_cutoff):
    '''
    Removes records that share a song title with another record. Returns the
    transformed dataset as well as a list of dataframes eachcontaining the 
    records for a particular song title.
    '''
    # Grab titles with duplicates
    # Note we lowercase, replace "-" with spaces, and remove all other non-alphanumeric characters from the titles
    characters = string.printable[62:-6]
    pattern = "[" + characters + "]"
    title_freq = data['song'].str.lower().str.replace('-',' ').str.replace(pattern, '').value_counts()
    duplicate_titles = title_freq[title_freq > 1]
    
    # Remove songs with duplicated titles from dataset and add to list
    duplicate_songs = []
    for i in range(len(duplicate_titles)):
        title = duplicate_titles.index[i]
        duplicate_songs.append(dataset[dataset['song'].str.lower().str.replace('-',' ').str.replace(pattern, '') == title])
        data = data.drop(dataset.index[dataset['song'].str.lower().str.replace('-',' ').str.replace(pattern, '') == title])
        
    # Iterate over each set of duplicated titles, calculate fuzzy match rates, and keep songs below fuzzy_cutoff
    # If no songs below fuzzy cutoff, grab first song
    unique_sets = [data.copy()]
    for subset in duplicate_songs:
        fuzzy_test = fuzzyCompare(subset)
        unique_records = fuzzy_test[fuzzy_test['max_fuzzy_match'] < fuzzy_cutoff]
        if len(unique_records) == 0:
            unique_records = fuzzy_test.iloc[0:1]
        unique_sets.append(unique_records.drop(columns = ['max_fuzzy_match'], axis = 1))
    
    # Append unique songs back onto our dataset
    data = pd.concat(unique_sets)
    
    return data.sort_index()

# %% [markdown]
# Now lets run the function on our dataset and print some statistics to make sure it's working. NOTE - the dedupe function may take a while to run since it is comparing so many long string values. For me it took ~10 minutes.

# %%
# set cutoff values
fuzzy_cutoff = 90

# Remove duplicates
dataset = DedupeDataset(dataset.copy(), fuzzy_cutoff)

# Display deduped dataset
dataset
# Out:
#              artist                   song  \
# 0              ABBA  She's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                                     text
# 0      Look at her face, it's a wonderful face  \nAnd...
# 1      Take it easy with me, please  \nTouch me gentl...
# 2      I'll never know why I had to go  \nWhy I had t...
# 3      Making somebody happy is a question of give an...
# 4      Making somebody happy is a question of give an...
# ...                                                  ...
# 57645  Irie days come on play  \nLet the angels fly l...
# 57646  Power to the workers  \nMore power  \nPower to...
# 57647  all you need  \nis something i'll believe  \nf...
# 57648  northern star  \nam i frightened  \nwhere can ...
# 57649  come in  \nmake yourself at home  \ni'm a bit ...
#
# [52808 rows x 3 columns]

# %%
# display some useful statistics
dataset.info()
dataset.describe(include = 'all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52808 entries, 0 to 57649
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   artist  52808 non-null  object
#  1   song    52808 non-null  object
#  2   text    52808 non-null  object
# dtypes: object(3)
# memory usage: 1.6+ MB
#                   artist     song  \
# count              52808    52808
# unique               643    44627
# top     Gordon Lightfoot  Hold On
# freq                 184       25
#
#                                                      text
# count                                               52808
# unique                                              52776
# top     The last verse was the hardest the hardest to ...
# freq                                                    2

# %% [markdown]
# Above we see that we removed a significant chunk of duplicate songs, 4,842 to be exact. Good thing we used fuzzy matching between song text too, since there are plenty of instances where the same title is shared across multiple uncorrelated songs. One such example shown in the statistics above is the 25 songs titled 'Hold On'. Below you can see that they are clearly unique.

# %%
dataset[dataset['song'] == 'Hold On']
# Out:
#                   artist     song  \
# 3225       Cliff Richard  Hold On
# 5375        Eric Clapton  Hold On
# 7253           Green Day  Hold On
# 10895               Korn  Hold On
# 15679          Pearl Jam  Hold On
# 15830      Pet Shop Boys  Hold On
# 21612       Wishbone Ash  Hold On
# 21820             Xscape  Hold On
# 22005                Yes  Hold On
# 22057   Yngwie Malmsteen  Hold On
# 26581  Bruce Springsteen  Hold On
# 27410            Chicago  Hold On
# 29226        Deep Purple  Hold On
# 31493     Emmylou Harris  Hold On
# 39788       Kelly Family  Hold On
# 40251          Kim Wilde  Hold On
# 42071           Lou Reed  Hold On
# 42255         Lucky Dube  Hold On
# 43663      Michael Buble  Hold On
# 44834       Natalie Cole  Hold On
# 49724           R. Kelly  Hold On
# 50432      Reba Mcentire  Hold On
# 51302            Santana  Hold On
# 51526              Selah  Hold On
# 53584          Tom Waits  Hold On
#
#                                                     text
# 3225   Love show me the way when I am lost and hope b...
# 5375   Deep down in the dead of night I call out your...
# 7253   As I stepped to the edge  \nBeyond the shadow ...
# 10895  With aversion this distortion  \nCame so swift...
# 15679  I was doom riding on top a black horse  \nWhat...
# 15830  Hold on, hold on,  \nThere's got to be a futur...
# 21612  Checked in tonight, when I noticed the red lig...
# 21820  I can make  \nAny man do whatever it takes  \n...
# 22005  Justice to the left of you  \nJustice to the r...
# 22057  Look at me, see the love that you're missing  ...
# 26581  Verse 1:  \nI worked hard, baby, night and day...
# 27410  Why, why, why won't you sympathize  \nAnd tell...
# 29226  You're sweeter than the morning  \nWhen the su...
# 31493  What happened to your mother's love  \nWhat ha...
# 39788  I wake up and see a suicide,  \nStanding out i...
# 40251  In the day I can smile though I want to die  \...
# 42071  There's blacks with knives and whites with gun...
# 42255  I knew exactly  \nWhat you were going through ...
# 43663  Didn't they always say we were the lucky ones?...
# 44834  You know, of all the things in the world I'd m...
# 49724  Wars, walls, tumble and falls  \nTime, change,...
# 50432  Hold on cause this feels just like a first lov...
# 51302  Don't rush me just this once  \nI want to make...
# 51526  If you feel today that you can't make it  \nKe...
# 53584  They hung a sign up in our town  \n"If you liv...

# %% [markdown]
# With that said, there is still clearly room for improvement. Above we see that there are still cases where multiple records share the exact same text. For example, the song "The Very Thought Of You" still shows up twice in our dataset with the exact same text for each. Turns out the two records have slightly different titles, with the other being "Very Thought Of You", which is why we did not try comparing or removing them. There are numerous examples of this behavior. To try and address it, below we wrote another function that removes any duplicates with the exact same text. Note this takes about 5 minutes to run.

# %%
# Function that removes duplicate records with the exact same text
def DedupeText(data):
    '''
    Function that removes duplicate records that share the same text value. We
    lowercase the text before comparing, as well as remove all non-alphanumerical
    characters to account for minor formatting differences.
    '''
    # Grab titles with duplicates
    # Note we lowercase and remove all other non-alphanumeric characters from text
    text_freq = data['text'].str.lower().str.replace('[\W_]+','').value_counts()
    duplicate_text = text_freq[text_freq > 1]
    
    # Remove songs with duplicated text from dataset and add to list
    duplicate_songs = []
    for i in range(len(duplicate_text)):
        text = duplicate_text.index[i]
        duplicate_songs.append(dataset[dataset['text'].str.lower().str.replace('[\W_]+','') == text])
        data = data.drop(dataset.index[dataset['text'].str.lower().str.replace('[\W_]+','') == text])
        
    # Iterate over each set of duplicated titles grab first song and place back in dataset
    unique_sets = [data.copy()]
    for subset in duplicate_songs:
        unique_records = subset.iloc[0:1]
        unique_sets.append(unique_records)
    
    # Append unique songs back onto our dataset
    data = pd.concat(unique_sets)
    
    return data.sort_index()

# %%
# Remove duplicate Text
dataset = DedupeText(dataset.copy())

# Display new dataset
dataset
# Out:
#              artist                   song  \
# 0              ABBA  She's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                                     text
# 0      Look at her face, it's a wonderful face  \nAnd...
# 1      Take it easy with me, please  \nTouch me gentl...
# 2      I'll never know why I had to go  \nWhy I had t...
# 3      Making somebody happy is a question of give an...
# 4      Making somebody happy is a question of give an...
# ...                                                  ...
# 57645  Irie days come on play  \nLet the angels fly l...
# 57646  Power to the workers  \nMore power  \nPower to...
# 57647  all you need  \nis something i'll believe  \nf...
# 57648  northern star  \nam i frightened  \nwhere can ...
# 57649  come in  \nmake yourself at home  \ni'm a bit ...
#
# [52731 rows x 3 columns]

# %%
# Show statistics
dataset.info()
dataset.describe(include = 'all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52731 entries, 0 to 57649
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   artist  52731 non-null  object
#  1   song    52731 non-null  object
#  2   text    52731 non-null  object
# dtypes: object(3)
# memory usage: 1.6+ MB
#                   artist     song  \
# count              52731    52731
# unique               643    44562
# top     Gordon Lightfoot  Hold On
# freq                 184       25
#
#                                                      text
# count                                               52731
# unique                                              52731
# top     So much pain and no good reason why  \nYou've ...
# freq                                                    1

# %% [markdown]
# As shown above, we removed another 77 songs from our dataset and no longer have any records with duplicte text. This does not guarantee that all our remaining records are distinct, but brings us most of the way there. There is always the possibility that two records are the same song technically, but they have slightly differently worded titles and slightly altered lyrics. However, these are unlikely and would be too much effort to remove on a case by case basis. We are happy with the current state of our dataset and will now move on to preparing the final records for analysis.

# %% [markdown]
# ### 2) Normalizing Song Text
#
# The neural network models we train will pick up and imitate the same patterns that occur in the text of our songs. As such, we want to make sure that the patterns the model should learn are very clear and the patterns it should not learn are removed or at least minimized.
#
# The types of patterns we don't want our model to learn are abnormalities and formatting shorthands that are present in a lot of the song text. For example, comments on the artist, song version, etc. at the start of the song or text that indicates repeated versus in the lyrics, such \[Chorus\] or \[Chorus:\].
#
# The types of patterns we do want our model to learn are the breaks between verses, ends of lines, and the beginning/end of songs. These aren't clear to our models so we will want to add clear markers to the text to indicate thes occurances. By doing so, we hope to aid our model in identifying, learning, and generating these patterns and sructures.
#
# Firstly, let's try to remove certain abnormalities that are present in our songs on a case by case basis. The types of issues we have noticed and need to address include the following:
#
#     1) Verse Placeholders: such as \[Verse\] or \[Chorus\]
#     2) Comments: additional information about the song within parenthesis within the song. Ex, backup vocals, who is singing, etc.
#     3) Extraneous Characters: Double spaces, empty lines, unwanted characters
#     4) Remove Proper Nouns: Names and Places
#     5) Capitalization: so capitalized words aren't considered different, reduce everything to lowercase
#
# #### Removing Verse Placeholders
#
# The most important of these three issues is probably the verse placeholders. These are in the song lyrics to either indicate the different sections of the song and/or to repeat these sections within explicitly repeating the whole text. However, I find it unlikely that our model would pick up on these conventions since they are very high level and used sporadically within our dataset. As such, it is probably best we remove them entirely and replace the placeholders with the text they mean to represent. Then we can just hope and pray that our model understands that verses tend to repeat when it trains on thousands of songs with repeating verses. To help us understand what we ned to accomplish, below are a few examples of these placeholders within song text.

# %%
my_song_1 = dataset[dataset['song']=='Bad Sneakers']
print('Artist: ' + my_song_1.iloc[0]['artist'])
print('Title: ' + my_song_1.iloc[0]['song'])
print(my_song_1.iloc[0]['text'])

my_song_2 = dataset[dataset['song']=='Just A Little Bit Of Your Heart']
print('Artist: ' + my_song_2.iloc[0]['artist'])
print('Title: ' + my_song_2.iloc[0]['song'])
print(my_song_2.iloc[0]['text'])
# Out:
# Artist: Steely Dan
# Title: Bad Sneakers
# Five names that I can hardly
# Stand to hear
# Including yours and mine
# And one more chimp who isn't here
# I can see the ladies talking
# How the times are getting hard
# And that fearsome excavation
# On Magnolia Boulevard
#
# [CHORUS:]
# And I'm going insane
# And I'm laughing at the frozen rain
# And I'm so alone
# Honey when they gonna send me home
# Bad sneakers and a Pina Colada
# My friend
# Stompin' on the avenue
# By Radio City with a
# Transistor and a large
# Sum of money to spend
#
# You fellah, you tearin' up the street
# You wear that white tuxedo
# How you gonna beat the heat
# Do you take me for a fool
# Do you think that I don't see
# That ditch out in the valley
# That they're digging just for me
#
# [CHORUS]
#
#
# Artist: Ariana Grande
# Title: Just A Little Bit Of Your Heart
# [Verse 1]
# Oh, oh, oh, oh
# I don't ever ask you where you've been
# And I don't feel the need to
# Know who you're with
# I can't even think straight but I can tell
# That you were just with her
# And I'll still be a fool
# I'm a fool for you
#
# [Chorus]
# Just a little bit of your heart
# Just a little bit of your heart
# Just a little bit of your heart is all I want
# Just a little bit of your heart
# Just a little bit of your heart
# Just a little bit is all I'm asking for
# Oh, oh, oh, oh
#
# [Verse 2]
# I don't ever tell you how I really feel
# Cause I can't find the words to say what I mean
# And nothing's ever easy
# That's what they say
# I know I'm not your only
# But I'll still be a fool
# Cause I'm a fool for you
#
# [Chorus]
# Just a little bit of your heart
# Just a little bit of your heart
# Just a little bit of your heart is all I want
# Just a little bit of your heart
# Just a little bit of your heart
# Just a little bit is all I'm asking for
# Oh, oh, (Just a little bit) oh, oh (Hallelujah)
#
# [Bridge]
# (Just a little bit, oh yeah)
# I know I'm not you're only
# But at least I'm one
# I hear a little love is better than none
# Oh babe
#
# [Chorus]
# Just a little bit of your heart
# Just a little bit of your heart
# Just a little bit of your heart is all I want
# Just a little bit of your heart
# Just a little bit of your heart
# Just a little bit is all I'm asking for
#
# [Chorus]
# Just a little bit of your heart
# Just a little bit of your heart (Just a little bit baby)
# Just a little bit of your heart is all I want (Is all I want)
# Just a little bit of your heart (Just a little bit)
# Just a little bit of your heart (Just a little bit)
# Just a little bit is all I'm asking for

# %% [markdown]
# Notice the first song is an example of where the placeholders represent chunks of the song. The section below "\[Chorus:\]" defines what the chorus is, and the next use of "\[Chorus\]" is meant to repeat this chunk of lyrics. In the second song we see an example of these placeholders simply identifying the different structural components of the song, from verses, to chorus, bridges, etc. These will be a bit easier to handle since they don't replace any text, so we just need to remove the placeholders. Before we go pulling sections from our song, lets try and identify what types of placeholders we have. Below we scan over our song texts and pull out these various placeholders.

# %%
import re

# define function to remove words in brackets from string
def BracketFinder(text):
    return re.findall('\[(.*?)\]', text)

# initiate list of text in brackets
bracket_text = []

# iterate over the text for all songs
for index, record in dataset.iterrows():
    text = record['text']
    bracket_words = BracketFinder(text)
    if len(bracket_words) > 0:
        for word in bracket_words:
            bracket_text.append(word)
bracket_text = sorted(set(bracket_text))

# Display text found
print(len(bracket_text))
bracket_text
# Out:
# 3278
# ['',
#  ' ',
#  ' -CHORUS-',
#  ' 12str guitar ',
#  ' 1989 version - Find your Brothers and sisters ',
#  ' 1990 version - Find your sisters and brothers ',
#  ' 5x ',
#  ' CHORUS: Benzalino ',
#  ' Chorus ',
#  ' Chorus - "I\'ll see you coming..." ',
#  ' Chorus - x2 ',
#  ' Chorus x3 ',
#  ' Chorus: ',
#  ' Dolly Parton ',
#  ' Fade ',
#  ' Lil Wayne ',
#  ' PREJUDICE ',
#  ' Pa pa pa pa pa pa ',
#  ' Paul McCartney Lyrics are found on www.songlyrics.com ',
#  ' Repeat ',
#  ' The Tragically Hip Lyrics are found on www.songlyrics.com ',
#  ' VERSE 1: Yukmouth ',
#  ' VERSE 2: Yukmouth ',
#  ' VERSE 3: Yukmouth ',
#  ' Vertical Horizon Lyrics are found on www.songlyrics.com ',
#  ' ac. Guitar ',
#  ' ac.guitar ',
#  ' ac.guitar - steel ',
#  ' ac.guitar - strings ',
#  ' ad lib ',
#  ' banjo ',
#  ' banjo - guitar ',
#  ' choir ',
#  ' dobro ',
#  ' dobro - sax ',
#  ' dobro - steel ',
#  ' duet with Mike Post ',
#  ' end of extra lyrics from 12" remix ',
#  ' extra lyrics from 1989 12" remix ',
#  " feat. Lani misalucha recorded by regine velasquez for kris aquino's album ",
#  ' fiddle ',
#  ' fiddle - ac.guitar ',
#  ' fiddle - banjo ',
#  ' fiddle - dobro ',
#  ' fiddle - guitar ',
#  ' fiddle - organ ',
#  ' fiddle - steel ',
#  ' guitar ',
#  ' guitar - banjo ',
#  ' guitar - fiddle ',
#  ' guitar - piano ',
#  ' guitar - piano - fiddle - steel ',
#  ' guitar - steel ',
#  ' harmonica ',
#  ' harmonica - steel ',
#  ' israel houghton lyrics are found on www.songlyrics.com ',
#  ' mandolin - dobro ',
#  ' organ ',
#  ' piano ',
#  ' piano - guitar ',
#  ' piano - steel ',
#  " recorded by mr. Pure energy Gary V for kris aquino's album ",
#  ' sax ',
#  ' sax - banjo ',
#  ' steel ',
#  ' steel - fiddle ',
#  ' steel - fiddle - guitar ',
#  ' steel - guitar ',
#  ' steel - piano ',
#  ' strings ',
#  ' trumpet ',
#  ' trumpet - guitar ',
#  ' vibes ',
#  '"Chicago" Soundtrack',
#  '"Data bank" repeats in BG \'til end',
#  '"Halley\'s Comet" over doo-wop',
#  '"Just let me listen to that."',
#  '"ay" is vocalized',
#  '"wide" repeats',
#  "'Cause a good gal nowadays is hard to find.",
#  "'Cause they're dancin'!",
#  "'cause I got you in my car, and you ain't going nowhere bitch, you're dead",
#  "'cause the moon told me to, and it's watching us right now",
#  "'cause we parked all alone and it's real dark anyway, hey",
#  "'re",
#  "(Ain't nobody's business)",
#  "(Cuz you're the one for me)",
#  "(I swear I'm keeping you satisfied)",
#  '(Lauryn "L-Boogie" Hill) Singing in parentheses',
#  "(Like I'm Tyra) Pause",
#  '(My lonely days are gone)',
#  '(You knock me off of my feet darling)',
#  '(You really turn me on)',
#  '-CHORUS-',
#  '-Chorus-',
#  '-Intro-',
#  '-Repeat Chorus until fade-',
#  '-Repeat Chorus-',
#  '-Verse 1-',
#  '-Verse 2-',
#  '-Verse 3-',
#  '-Verse 4-',
#  '..',
#  '...',
#  '... Where she meets Valjean.',
#  '.... Fades To End',
#  '...?',
#  '00: 46',
#  '00: 56',
#  '01: 04',
#  '01: 06',
#  '01: 12',
#  '01: 34',
#  '01: 43',
#  '01: 51',
#  '01: 52',
#  '01: 59',
#  '02: 04',
#  '02: 13',
#  '02: 16',
#  '02: 19',
#  '02: 27',
#  '02: 36',
#  '02: 39',
#  '02: 43',
#  '02: 52',
#  '03: 01',
#  '03: 10',
#  '03: 19',
#  '03: 26',
#  '03: 28',
#  '03: 34',
#  '03: 39',
#  '03: 41',
#  '03: 47',
#  '1',
#  '1 x',
#  '10x',
#  '12X',
#  '12x',
#  "15x's",
#  "16x's",
#  '1940s',
#  '19x',
#  '1st Chorus: add Nas after each pause',
#  '1st Chorus: after Nas add Puff Daddy ad lib',
#  '1st Verse',
#  '1st Vrs',
#  '1st child',
#  '1st verse',
#  '1st verse:',
#  '2',
#  '2 x Chorus:',
#  '21 second instrumental to open',
#  '2nd Verse',
#  '2nd Vrs',
#  '2nd child',
#  '2nd chorus',
#  '2nd chorus:',
#  '2nd verse:',
#  '2x',
#  '2xs',
#  '3',
#  '3 x',
#  '3: Forget him, love',
#  '3X',
#  '3rd Verse',
#  '3rd chorus:',
#  '3rd verse:',
#  '3x',
#  '4',
#  '4 Fizzle:',
#  '4X',
#  '4x',
#  '4xs',
#  '50 Cent',
#  '5X',
#  '5x',
#  '6 John',
#  '6 times',
#  '6x',
#  '7X',
#  '8: 08',
#  '8X',
#  '8x',
#  '?',
#  '? ',
#  '? The engine burns hot?',
#  "? We'll end up heading?",
#  '??',
#  '???',
#  '????',
#  '???????',
#  '??????????????',
#  '?????????????????????????????',
#  'A',
#  'A dog, a dog! Why?',
#  'A7',
#  'AC. Guitar ',
#  'AJ:',
#  'ALL',
#  'ANNA',
#  'ANNIE',
#  'ANNIE and MOLLY',
#  'Aaliyah',
#  'Actual lyrics as sung:',
#  'Ad lib fade',
#  'Ad lib until fade',
#  'Ad libs',
#  'Adam Sandler',
#  'Adlib line 2:',
#  "Ah, goodbye muscles. I don't need you anymore",
#  'Ahoohoh',
#  "Ain't nobody's business",
#  "Ain't shit changed, bitch check us",
#  'Aj:',
#  'Akon',
#  'Alan',
#  'Alan Jackson',
#  'Alice',
#  'Alien',
#  'All',
#  'All Members',
#  'All Star',
#  'All again',
#  'All in docket:',
#  "All this player hatin' getting me pissed",
#  'All three:',
#  'All:',
#  'Ally',
#  'Ally 4x',
#  'Alternate line:',
#  'Alto',
#  'Am',
#  'Amanda Diva:',
#  'Amber of Dirty Projectors',
#  'Ampichino',
#  'An old beggar woman finds a young prostitute occupying her patch.',
#  'And I say to myself',
#  'And fly outside with them',
#  'And put the smack down on your lips',
#  'And this battle is not yours',
#  'And we ?? his little behind, bitch, bring it on',
#  'And we the poor drunks',
#  'Andre',
#  'Andre 3000',
#  'Andy',
#  'Andy and Kol',
#  'Ang ibong malaya',
#  'Ang tibok ng puso',
#  'Angela',
#  'Anna interrupts then starts them over',
#  'Annie:',
#  'Announcer',
#  'Answering Machine',
#  'Anytime',
#  'Applause from the dancers as the waltz finishes.',
#  'Arab or Hebrew lyrics',
#  'Are you ready to go',
#  'Assume the position',
#  'Aw commation',
#  'Aw ya love that?',
#  'Aw you love that?',
#  'Aw, come on Nicky. Win me a koala bear',
#  'Aww, come on muscles',
#  'B SECTION',
#  'B-Real',
#  'B. G.',
#  'B.G.',
#  'B.I.G.',
#  'B.I.G.chant',
#  'B.K.',
#  'B2k',
#  'B:',
#  'BACK TO CHORUS',
#  'BDG',
#  'BIG',
#  'BIlly to Jesse',
#  'BR',
#  'BRIDGE',
#  'BRIDGE:',
#  'BS',
#  'Ba ba ba ba ba ba etc continuous background to end',
#  'Baby',
#  'Baby loves that way',
#  'Baby, close your eyes',
#  'Backbone',
#  'Background',
#  'Background voices continue',
#  'Background:',
#  'Backing Singers:',
#  'Baekhyun',
#  'Bamatabois is a well dressed gentleman.',
#  'Bang!',
#  'Barbra',
#  'Barbra Streisand',
#  'Barbra:',
#  'Barnaby:',
#  'Base Chorus: Puff Daddy',
#  'Bb',
#  'Beat break',
#  'Beating sounds',
#  'Bekhyun',
#  'Below',
#  'Benzino',
#  'Bette',
#  'Bette:',
#  'Big Azz Ko',
#  'Big Boi',
#  'Big Gipp',
#  'Big Mello',
#  'Big Mike:',
#  'Big Sean',
#  'Big Tigger',
#  'Bigge',
#  'Biggie',
#  'Biggie mom',
#  'Billie:',
#  'Billy',
#  'Billy Ray',
#  'Birdman',
#  'Bizzy Bone',
#  'Black Eyed Peas',
#  'Black Rob',
#  'Bleeping',
#  'Bleeping noise',
#  'Blige',
#  'Blue grey',
#  'Bob Rivers as Eminem:',
#  'Bob Rivers:',
#  'Bonus track',
#  'Boom',
#  'Boosie',
#  'Both',
#  'Both:',
#  'Boy:',
#  'Boys',
#  'Break',
#  'Break 1',
#  'Break 2',
#  'Break-Down 1',
#  'Break-Down 2',
#  'Break:',
#  'Break: Carl Thomas',
#  'Breakdown',
#  'Breakdown to Nicki Minaj part',
#  'Breakdown:',
#  'Brendon',
#  'Brendon and Nate',
#  'Brendon screams',
#  'Brian McKnight',
#  'Brian:',
#  'Bridge',
#  'Bridge (LaTocha):',
#  'Bridge (R Kelly)',
#  'Bridge (Tamika):',
#  'Bridge (x2)',
#  'Bridge - Chris Brown',
#  'Bridge - Girl',
#  'Bridge - Rohff',
#  'Bridge - Uncle Charlie Wilson',
#  'Bridge - repeat 2x',
#  'Bridge 1',
#  'Bridge 1: Kate Bush, Chorus',
#  'Bridge 1: Lil Wayne',
#  'Bridge 1: Nicki Minaj',
#  'Bridge 2',
#  'Bridge 2: Lil Wayne',
#  'Bridge 2: Nicki Minaj',
#  'Bridge 3',
#  'Bridge 4',
#  'Bridge guitar solo 1',
#  'Bridge guitar solo 2',
#  'Bridge x 2',
#  'Bridge x2',
#  'Bridge x2:',
#  'Bridge x4',
#  'Bridge x5',
#  'Bridge:',
#  'Bridge: All',
#  'Bridge: Andre 3000',
#  'Bridge: Ariana Grande',
#  'Bridge: Chris Brown',
#  'Bridge: Flo Rida',
#  'Bridge: Harmonization',
#  'Bridge: Harry',
#  'Bridge: Harry Styles',
#  'Bridge: Instrumental',
#  'Bridge: Jade',
#  'Bridge: John Legend',
#  'Bridge: Justin Timberlake',
#  'Bridge: Kanye West',
#  'Bridge: Kate Bush',
#  'Bridge: Liam Payne',
#  'Bridge: Madonna',
#  'Bridge: Mike Shorey',
#  'Bridge: Ne-Yo',
#  'Bridge: Nelly',
#  'Bridge: Niall',
#  'Bridge: Niall Horan x2',
#  'Bridge: Nicki Minaj',
#  'Bridge: Normani',
#  'Bridge: Pitbull',
#  'Bridge: Rell',
#  'Bridge: Rihanna',
#  'Bridge: Ron Isley',
#  'Bridge: Skylar',
#  'Bridge: Snoop Dogg',
#  'Bridge: T-Pain',
#  'Bridge: The Weeknd',
#  'Bridge: Usher',
#  'Bridge: Zara Larsson',
#  'Bridge: Zayn Malik',
#  'Bridge: lil wayne',
#  'Bridge: x1',
#  'Bridge: x2',
#  'Bridgex2',
#  'Bring you and your fat-ass bich inside',
#  'Brisco',
#  'Britney Spears',
#  'Britney Spears, ladies and gentleman',
#  'Broadway',
#  'Bruno Mars',
#  'Buffoon continues to eat popcorn',
#  'Buffoon continues to walk away',
#  'Buffoon eating popcorn',
#  'Buffoon walking away',
#  'Bun B',
#  'Bun B:',
#  'Burning up for your love',
#  'Busta Rhymes',
#  'Buster, you gotta be kidding, you see this little guy?',
#  'But if you wanna come back, come on in our little grass shack,',
#  'But mine and my baby',
#  "But mine and my baby's",
#  'But my luck is always bad',
#  "But we don't have a woman",
#  "But when you think that you got her tied, you'll find her",
#  'But you can see the green glow I make',
#  'Buzz:',
#  'C',
#  'C-Bo',
#  'C.Gee',
#  'C7',
#  'CD version:',
#  'CED-GEE',
#  'CH',
#  'CHILD SINGING',
#  'CHILDREN',
#  'CHORUS',
#  'CHORUS ',
#  'CHORUS (2X):',
#  'CHORUS (repeat 2X)',
#  'CHORUS (repeat ad inf.)',
#  'CHORUS (repeat)',
#  'CHORUS (x2)',
#  'CHORUS 2X',
#  'CHORUS OUT',
#  'CHORUS X 2',
#  'CHORUS X 6',
#  'CHORUS:',
#  'Cadillac Tah',
#  'Caller',
#  "Cam'Ron",
#  "Cam'ron",
#  'Camila',
#  'Can you feel all the love',
#  "Can't nobody get with these, motherfucker, bring it on!",
#  "Can't nothing stop the rain, bitch, bring it on",
#  'Cappadonna',
#  'Car Crashes',
#  'Carl Thomas',
#  'Ced Gee',
#  'Cee-Lo',
#  'Cee-lo, Chorus',
#  'Celine',
#  'Chairs',
#  'Chamillionaire',
#  'Chamillonare Verse 2',
#  'Channel:',
#  'Chant',
#  'Chanyeol',
#  'Children laughing',
#  "Children's choir singing in the background",
#  'Chilli',
#  'China Dog',
#  'Choir ',
#  'Chorus',
#  'Chorus ',
#  'Chorus (10x)',
#  'Chorus (14x)',
#  'Chorus (1x)',
#  'Chorus (2x)',
#  'Chorus (3X)',
#  'Chorus (3x)',
#  'Chorus (4x)',
#  'Chorus (5x)',
#  'Chorus (9x)',
#  'Chorus (Girl)',
#  'Chorus (Just Guy)',
#  'Chorus (Out)',
#  'Chorus (Tra-Knox)',
#  'Chorus (emphasis on AJ):',
#  'Chorus (mainly AJ):',
#  'Chorus (mainly Nick):',
#  'Chorus (until fade)',
#  'Chorus (x)',
#  'Chorus (x2)',
#  'Chorus (x4)',
#  'Chorus - 2x',
#  'Chorus - 3x',
#  'Chorus - 4x',
#  'Chorus - 6x',
#  'Chorus - A.H. singing (Xzibit)',
#  'Chorus - Both Sing',
#  'Chorus - Chris Brown',
#  'Chorus - Extended',
#  'Chorus - Ill Will',
#  'Chorus - Joe Beast',
#  'Chorus - John Ryan',
#  'Chorus - Justin Timberlake',
#  'Chorus - Nicole',
#  'Chorus - Pharrell',
#  'Chorus - Sean Paul',
#  'Chorus - Snoop Dogg',
#  'Chorus - Talib Kweli',
#  'Chorus - Variation',
#  'Chorus - Xzibit',
#  'Chorus - Z-Ro',
#  'Chorus - lil wayne',
#  'Chorus - repeat 2X',
#  'Chorus - repeat 4X',
#  'Chorus - x2',
#  'Chorus 1',
#  'Chorus 1 - 2x',
#  'Chorus 1 B.I.G.',
#  'Chorus 1 x2',
#  'Chorus 1(3x)',
#  'Chorus 1:',
#  'Chorus 1: Fabolous',
#  'Chorus 1: Kate Bush',
#  'Chorus 1: Marvin Gaye (Snoop Dogg)',
#  'Chorus 1: x 2 b-Real',
#  'Chorus 1: x2',
#  'Chorus 1x',
#  'Chorus 2',
#  'Chorus 2 Lil Kim',
#  'Chorus 2 x3',
#  'Chorus 2(out)',
#  'Chorus 2:',
#  'Chorus 2: Everlast',
#  'Chorus 2: Kate Bush',
#  'Chorus 2: Mariah Carey (Ja Rule)',
#  'Chorus 2: Marvin Gaye',
#  'Chorus 2: Repeats',
#  'Chorus 2: The Weeknd and Maty Noyes',
#  'Chorus 2: x2',
#  'Chorus 2X',
#  'Chorus 2X: Ghostface Killah (Raekwon)',
#  'Chorus 2X: X-Raided',
#  'Chorus 2X: Z-Ro',
#  'Chorus 2x',
#  'Chorus 2x:',
#  'Chorus 3',
#  'Chorus 3 -Final',
#  'Chorus 3:',
#  'Chorus 3: Everlast',
#  'Chorus 3: Kate Bush',
#  'Chorus 3X',
#  'Chorus 3x',
#  'Chorus 4',
#  'Chorus 4x',
#  "Chorus 4x's",
#  'Chorus 5',
#  'Chorus 5x',
#  'Chorus 6x',
#  'Chorus 7x',
#  'Chorus 8X',
#  'Chorus :',
#  'Chorus : Tray Deee and Snoop Dogg',
#  'Chorus :x2',
#  'Chorus By Carl Thomas 4x..music fades out',
#  'Chorus I:',
#  'Chorus II:',
#  'Chorus To Fade',
#  'Chorus X2',
#  'Chorus iii',
#  'Chorus over last line',
#  'Chorus repeat',
#  'Chorus repeat- X2',
#  'Chorus repeat-X2',
#  'Chorus repeats',
#  'Chorus till fade',
#  'Chorus to Fade',
#  'Chorus to end',
#  'Chorus to fade',
#  'Chorus until fade',
#  'Chorus x 2',
#  'Chorus x 2:',
#  'Chorus x 3',
#  'Chorus x 4',
#  'Chorus x 5',
#  'Chorus x2',
#  'Chorus x2:',
#  'Chorus x2: Lil Brother First, Lil Wayne Second',
#  'Chorus x2: Lil Wayne First, Lil Brother Second',
#  'Chorus x2: Michael Jackson',
#  'Chorus x2: Ne-Yo',
#  'Chorus x2: trey songz',
#  'Chorus x3',
#  'Chorus x4',
#  'Chorus x7',
#  'Chorus(2x)',
#  'Chorus(out)',
#  'Chorus(x2)',
#  'Chorus(x2):',
#  'Chorus)',
#  'Chorus- Jennifer Lopez',
#  'Chorus-Trey Songz',
#  'Chorus:',
#  'Chorus: ',
#  'Chorus: (Both)',
#  'Chorus: (Miley)',
#  'Chorus: (R Kelly)',
#  'Chorus: 1',
#  'Chorus: 1x',
#  'Chorus: 2',
#  'Chorus: 2X',
#  'Chorus: 2x',
#  'Chorus: 4X',
#  'Chorus: Adam Levine',
#  'Chorus: Alicia Keys',
#  'Chorus: All',
#  'Chorus: All Members',
#  'Chorus: Ariana Grande',
#  'Chorus: Baby (Cristale)',
#  'Chorus: Big Boi',
#  'Chorus: Blaque (Mannie Fresh)',
#  'Chorus: Camila',
#  'Chorus: Carl Thomas',
#  'Chorus: Carl Thomas 2x',
#  'Chorus: Cee-Lo',
#  'Chorus: Chris Brown',
#  'Chorus: David Bowie',
#  'Chorus: Dexter Wiggles (RZA)',
#  'Chorus: Dinah',
#  'Chorus: Erykah Badu',
#  'Chorus: Fabolous',
#  'Chorus: Faith Evans',
#  'Chorus: GZA, (RZA)',
#  'Chorus: Harry',
#  'Chorus: Harry Styles',
#  'Chorus: Ice Cube',
#  'Chorus: Isley Bros',
#  'Chorus: Ja Rule',
#  'Chorus: Jamie Foxx (Ariana Grande)',
#  'Chorus: Jessie Ware',
#  'Chorus: John Legend',
#  'Chorus: Justin Bieber',
#  'Chorus: Kaine - 2X',
#  'Chorus: Kanye West',
#  'Chorus: Kokane',
#  'Chorus: Lauren',
#  'Chorus: Leigh-Anne',
#  'Chorus: Liam',
#  'Chorus: Liam and All',
#  'Chorus: Lil Mo',
#  "Chorus: Lil' Jon",
#  'Chorus: Louis',
#  'Chorus: Louis Tomlinson',
#  'Chorus: Macy',
#  'Chorus: Mannie Fresh',
#  'Chorus: Mary J. Blige',
#  'Chorus: Mashonda',
#  'Chorus: Michael Jackson',
#  'Chorus: Mike Shorey',
#  'Chorus: Missy Elliott',
#  'Chorus: Nate Dogg',
#  'Chorus: Ne-Yo',
#  'Chorus: Nelly Furtado',
#  'Chorus: Perrie',
#  'Chorus: Pharrell',
#  'Chorus: Q-Tip (Meda Leacock)',
#  'Chorus: Repeat',
#  'Chorus: Repeat 2X',
#  'Chorus: Repeat 2x',
#  'Chorus: Repeat 3X',
#  'Chorus: Repeat Til End',
#  'Chorus: Repeat x2',
#  'Chorus: Repeat x3',
#  'Chorus: Repeats',
#  'Chorus: Repeats till fade',
#  'Chorus: Rico Love',
#  'Chorus: Rihanna',
#  'Chorus: Rihanna and Kanye West',
#  'Chorus: Robin Thicke (Pitbull)',
#  'Chorus: Sean Paul',
#  'Chorus: Snoop (KoKane)',
#  'Chorus: Snoop Dogg (Fabolous)',
#  'Chorus: Soopafly',
#  'Chorus: Starrah',
#  'Chorus: Sunny Valentine (Tash Mahogany)',
#  'Chorus: The Persuasions "Gypsy Woman" sample',
#  'Chorus: The Weeknd',
#  'Chorus: Timbaland',
#  'Chorus: Tra-Knox',
#  'Chorus: Trey Songz',
#  'Chorus: Twista',
#  'Chorus: Unplugged',
#  'Chorus: Usher',
#  'Chorus: Variation',
#  'Chorus: Vein',
#  'Chorus: Wyclef',
#  'Chorus: X2',
#  'Chorus: Young Buck',
#  'Chorus: Zara Larsson',
#  'Chorus: Zayn',
#  'Chorus: repeat 2X',
#  'Chorus: repeat 2x',
#  'Chorus: repeat 4x',
#  'Chorus: repeat until fade',
#  'Chorus: see-Bo',
#  'Chorus: trey songz',
#  'Chorus: until end',
#  'Chorus: until fade',
#  'Chorus: x 2',
#  'Chorus: x 3',
#  'Chorus: x 4',
#  'Chorus: x10',
#  'Chorus: x2',
#  'Chorus: x3',
#  'Chorus: x4',
#  'Chorus: x5',
#  'Chorus: x6',
#  'Chorus: x7',
#  'Chorus: x8',
#  'Chorus:Repeat x2',
#  'Chorus:Repeat x3',
#  'Chorus:Repeat x4',
#  'Chorus:Repeat x5',
#  'Chorus:Repeats x2',
#  'Chorus:Repeatx3',
#  'Choruse',
#  'Chorusx2',
#  'Chorusx2... Fade',
#  'Chours ii',
#  'Chours: Both',
#  'Chourus',
#  'Chris',
#  'Chris Brown',
#  'Chris Brown:',
#  'Chris Until Fade',
#  'Chris brown - Chorus',
#  'Chris in a whisper',
#  "Chris' Rap",
#  'Chris: Talks',
#  'Christina',
#  'Christina (Nelly)',
#  'Christina (Nelly):',
#  'Christina:',
#  'Chrous',
#  'Chrous X 2',
#  'Chrous:',
#  'Chrous: Chris Brown',
#  'Chrous: Fabolous',
#  'Chrus',
#  'Chuck D:',
#  'Chuckles',
#  'Chuckling',
#  'Ciara',
#  "Cl'Che",
#  'Clears Throat',
#  'Cleveland:',
#  'Clown',
#  'Coda',
#  'Coda:',
#  'Come on',
#  'Come on baby',
#  'Come on be my girl',
#  'Come on now',
#  'Common',
#  'Company',
#  'Congregation',
#  'Consequence',
#  'Continue Chorus until fade',
#  'Cool Breeze',
#  'Cool J',
#  'Cool Keith',
#  'Cornelius speaking',
#  'Cornelius:',
#  'Cows mooing and carnival music plays in the background',
#  'Cristale',
#  'Crowds:',
#  'Cuban Link',
#  'Cubo',
#  'Cymphonique:',
#  'D',
#  'D-Reck:',
#  'D-Roc',
#  'D.O',
#  'D.O.',
#  'DJ Envy:',
#  'DJ Quik',
#  'DJ scramble',
#  'DP',
#  'DR. EDISON AMOS',
#  'DRAKE:',
#  'Da Brat',
#  'Damian Marley',
#  'Dance Break',
#  'Dante Ross',
#  'Darling',
#  'David Bowie',
#  'Day breaks.',
#  'Daz',
#  'Dead bigots, yeah, face down in a pond',
#  'Debra Killings',
#  'Deckard:',
#  'Dedicated to A. M. Klein (1909-1972)',
#  'Dedicated to Irving Layton',
#  'Dee Dee:',
#  'Dee Money Talkin',
#  'Dee Money Verse 1',
#  'Dee Money Verse 3',
#  'Defari',
#  'Defending the country he loves',
#  'Den Den',
#  'Dennis',
#  'Devil',
#  'Devin',
#  'Dial tone',
#  'Dialog',
#  'Dialogue',
#  'Diddy',
#  'Diddy - Dirty Money- Chorus',
#  'Diddy and Nicole',
#  'Diddy talking',
#  'Diddy:',
#  'Dinah',
#  'Dirty money',
#  'Disciples to Jesse',
#  'Disney movie',
#  'Dj Clue:',
#  'Dj Scratched',
#  'Dj scratching',
#  'Dj scratching to fade',
#  'Do7',
#  'Dobro',
#  'Dolly speaking',
#  'Dolly:',
#  "Don't mention at all",
#  "Don't say you're not because you are",
#  "Don't say your love",
#  "Don't say your, your love is",
#  "Don't tell me everything's gonna work out",
#  'Donna',
#  'Donna Summer',
#  'Doo doo doo',
#  'Door opens, walking towards her',
#  'Dottie:',
#  'Down wine',
#  'Dr. Dre',
#  'Dr. John',
#  'Dracula accent:',
#  'Drake',
#  'Drake - Verse 1',
#  'Drake - Verse 2',
#  'Drake:',
#  'Dre',
#  'Drop a dime on you',
#  'Drop: Nicki Minaj',
#  'Duet:',
#  'During Chorus',
#  'During the Could be famous...',
#  'E7',
#  'ENDYAMON "Show you no mercy, we\'re far from the Light in PURGATORY:',
#  'ENDYAMON:',
#  'ENRIQUE',
#  "Each day I'm falling more in love with you",
#  'Echo-Trey Songz',
#  'Ed Lover',
#  'Ed Sheeran',
#  'Eddie',
#  'Eddie and Mrs. Strakosh:',
#  'Eddie and Temptations',
#  'Eddie:',
#  'Edgar:',
#  'Eightball',
#  'Eli',
#  'Eminem',
#  'Eminem - Verse 1',
#  'Eminem - Verse 2',
#  "Eminem's Part",
#  'End',
#  'End Chorus',
#  'End chorus',
#  'Ending',
#  'Ending:',
#  'English verse',
#  'English: "I Want To Stay Like This"',
#  'Enjolras is addressing the revolutionaries.',
#  'Enrique',
#  'Enrique Iglesias',
#  'Eponine is alone in the square.',
#  'Errr',
#  'Esham',
#  'Establishment:',
#  'Estelle',
#  'Etc.',
#  'Eva:',
#  'Everlast',
#  'Everlast (Xzibit)',
#  'Except all, all, all',
#  'Excited Southerner',
#  'F',
#  "Fab talks 'til the end",
#  'Fabolous',
#  'Fabolous (talking):',
#  'Fabolous - Intro',
#  'Fabolous - Verse 1',
#  'Fabolous - Verse 2',
#  'Fabolous - Verse 4',
#  'Fabolous - talking',
#  'Fabolous Talking',
#  'Fabolous:',
#  'Face',
#  'Fade',
#  'Fade out',
#  'Fade...',
#  'Fading',
#  'Fagin',
#  'Fagin (spoken)',
#  'Fagin and boys',
#  'Faith Evans',
#  'Faith hill',
#  'Falls to the floor',
#  'Fanny:',
#  'Fantine goes off with one of the sailors.',
#  'Fantine re-emerges, her long hair cut short.',
#  'Feat Dee Money',
#  'Featuring cool Nick',
#  'Feel it as a...',
#  'Female Medic',
#  'Female Vocals',
#  'Female backgrounds:',
#  'Female version:',
#  'Fiddle',
#  'Fiddle - Mandolin ',
#  'Fight till death [Repeat x 3',
#  'First Chorus:',
#  'First Man:',
#  'First Verse',
#  'Flo Rida',
#  'Flo Rida - Bridge',
#  'Flo Rida:',
#  'Flo rida',
#  'For a good gal nowadays are hard to find.. Leroy!',
#  'Foreign Content',
#  'Fortunato:',
#  'Fortune',
#  'Frank:',
#  'Freddy',
#  'French Montana:',
#  'French Verse',
#  'French version of "Everyday Of Your Life"',
#  'From "Guys And Dolls"',
#  'From "Show Boat"',
#  'From "The Book of Jonah"',
#  'From Mark Knopfler\'s "Sailing To Philadelphia"',
#  'From this point on is actually from "Bad Time" by Grand Funk Railroad',
#  'Fundisha',
#  'Funkmaster Flex:',
#  'Fz synclavier',
#  'G',
#  'G. Dep',
#  'G.F.:',
#  'G7',
#  'GEORGE BUSH, SR.',
#  'GEORGE W. BUSH',
#  'GLC (Kanye West)',
#  'GUITAR SOLO',
#  'GZA',
#  'Gary',
#  'Gavroche',
#  'Gavroche enters.',
#  'Gavroche rushes in, shouting.',
#  'General',
#  'George',
#  'George Clinton',
#  'German translation:',
#  "Get a clue babe, there's nothing to talk about.",
#  'Gets out of the car',
#  'Ghost',
#  'Ghostface',
#  'Ghostface Killah',
#  'Girl',
#  'Girl Talking',
#  'Girl as Dina Rae:',
#  'Girl, do you believe',
#  'Girl:',
#  ...]

# %% [markdown]
# Above we see that there are over 3,000 different words/phrases found between brackets within our songs. Most of these are just additional song info that we will delete later, but some of them indicate the repeating patterns we need to replace. The key is going to be identifying which of these phrases to use. Below we wrote a function to find and print the text of songs with a few of these idenitfyers to help us sift through our possible choses.

# %%
# function that finds all songs with given phrase between brackets
def FindBracketSongs(data, bracket_phrase):
    records = []
    for i in range(len(data)):
        text = data.iloc[i]['text']
        if re.search(bracket_phrase, text):
            records.append(data.iloc[i:i+1])
    
    return pd.concat(records)

# %%
# Example, find all occurences of [Chorus x 2]
bracket_phrase = '\[Chorus X2\]'
text_samples = FindBracketSongs(dataset, bracket_phrase)
text_samples
# Out:
#             artist             song  \
# 16723     R. Kelly  Ghetto Religion
# 43082  Mark Ronson  In Case Of Fire
#
#                                                     text
# 16723  Had the landlord at my door  \nI heard him say...
# 43082  [Verse 1]  \nBurnin' up, the second Adderall  ...

# %%
# full text for specific song
print(text_samples.iloc[0]['text'])
text_samples.iloc[0]['text']
# Out:
# Had the landlord at my door
# I heard him saying,
# Tomorrow no more
# Pay me now or leave
# But we didn't have anything to give(ah can you feel me)
#
# Searching for restoration(and we need restoration)
# Make the church my family
# This is my story
# This is my song
# And I can sing it all night long I tell you why because,
#
# [Chorus]
#
# The ghetto is a part of my religion(the only thing my eyes can see)
# The only thing my eyes can see(and I tell you there ain't no man)
# There ain't no man gonna stop the vision(I'm a part of the ghetto)
# The ghetto is a part of me
#
# Children cry no more(children cry no more)
# Because heaven is upon you
# Please put down your guns
# And we shall overcome
#
# Thought your load may be heavy
# Know that the weight makes you strong
# Take my life for example
# While I sing my song
# Mr. Kelly help me sing this song
#
# [Chorus X2]
#
# La la la la la lala la..X3 (fade out)
# The ghetto is a part of me
# The ghetto is a part of my religion
# "Had the landlord at my door  \nI heard him saying,  \nTomorrow no more  \nPay me now or leave  \nBut we didn't have anything to give(ah can you feel me)  \n  \nSearching for restoration(and we need restoration)  \nMake the church my family  \nThis is my story  \nThis is my song  \nAnd I can sing it all night long I tell you why because,  \n  \n[Chorus]  \n  \nThe ghetto is a part of my religion(the only thing my eyes can see)  \nThe only thing my eyes can see(and I tell you there ain't no man)  \nThere ain't no man gonna stop the vision(I'm a part of the ghetto)  \nThe ghetto is a part of me  \n  \nChildren cry no more(children cry no more)  \nBecause heaven is upon you  \nPlease put down your guns  \nAnd we shall overcome  \n  \nThought your load may be heavy  \nKnow that the weight makes you strong  \nTake my life for example  \nWhile I sing my song  \nMr. Kelly help me sing this song  \n  \n[Chorus X2]  \n  \nLa la la la la lala la..X3 (fade out)  \nThe ghetto is a part of me  \nThe ghetto is a part of my religion\n\n"

# %% [markdown]
# After looking at countless examples of songs with these phrases within the text, we've decided that it would be too much trouble to try and account for every type of specific occurence. There is just no clear pattern between songs or even for specific phrases. As such, we've decided to just remove all records that have any of these phrases in their text. Thankfully, this is only about 20% of our dataset, which is significant, but our dataset is large enough that this shouldn't affect our model too much. The only downside is that the songs for certain artists have more of these formatting conventionalities than others and will be affected disproportionately.
#
# Before we delete all the songs with these phrases, we are going to do our best to fix the Steely Dan songs. This is the artist we want our model to mimic, so we need to maintain as many of the songs as possible. Thankfully, there are only a few instances of these bracketed phrases in the Steely Dan songs, primarily for indicating repeated choruses. Below we wrote some functions to identify these phrases in each song text, replace them with the actual chorus lyrics, and then remove the remaining phrases.

# %%
# function that replaces repeated choruses with the actual lyrics in our song text
def ReplaceChorus(data):
    # substrings we will look for
    start_phrases = ['[CHORUS:]  \n', '[Chorus:]  \n', 'Chorus:  \n', 'CHORUS:  \n',
                     '[CHORUS]  \n', '[Chorus]  \n', 'Chorus  \n', 'CHORUS  \n']
    end_phrases = ['  \n  \n', '  \n  \n', '  \n  \n', '  \n  \n',
                   '  \n  \n', '  \n  \n', '  \n  \n', '  \n  \n']
    repeat_phrases = ['[CHORUS]  \n  \n', '[Chorus]  \n  \n', 'Chorus  \n  \n', 'CHORUS  \n  \n',
                      '[CHORUS]  \n  \n', '[Chorus]  \n  \n', 'Chorus  \n  \n', 'CHORUS  \n  \n']
    end_chorus_phrases = ['[CHORUS]\n\n', '[Chorus]\n\n', 'Chorus\n\n', 'CHORUS\n\n',
                          '[CHORUS]\n\n', '[Chorus]\n\n', 'Chorus\n\n', 'CHORUS\n\n']
    
    text_list = []
    # Grab text for each song and store in list
    for index, record in data.iterrows():
        text_list.append(record['text'])
    
    # Iterate over each substring
    for i in range(len(start_phrases)):
        # Iterate over each song and replace chorus placeholders
        for j in range(len(text_list)):
            text = text_list[j]
            start_phrase = start_phrases[i]
            end_phrase = end_phrases[i]
            repeat_phrase = repeat_phrases[i]
            end_chorus_phrase = end_chorus_phrases[i]
            n = len(start_phrase)
            m = len(end_phrase)
            l = len(end_chorus_phrase)
            start = text.find(start_phrase) + n
            end = text[start:].find(end_phrase) + start + m
            if (start - n) != -1 and end - start - m != -1:
                chorus = text[start:end]
                text = text.replace(repeat_phrase, chorus)
                if text[-l:] == end_chorus_phrase:
                    text = text[:-l] + chorus[:-m] + '\n\n'
                text = text.replace(start_phrase, '')
            text_list[j] = text
    
    # Replace text column in dataset with new text
    data['text'] = text_list
    
    return data

# %%
# Run function on Steely Dan songs
steely_dan_songs = dataset[dataset['artist']=='Steely Dan']
steely_dan_songs = ReplaceChorus(steely_dan_songs.copy())

# %%
# Look at example before and after
before = dataset[dataset['song'] == "Rikki Don't Lose That Number"]
print('Before\n------')
print('Artist: ' + before.iloc[0]['artist'])
print('Title: ' + before.iloc[0]['song'])
print(before.iloc[0]['text'])
after = steely_dan_songs[steely_dan_songs['song'] == "Rikki Don't Lose That Number"]
print('After\n-----')
print('Artist: ' + after.iloc[0]['artist'])
print('Title: ' + after.iloc[0]['song'])
print(after.iloc[0]['text'])
# Out:
# Before
# ------
# Artist: Steely Dan
# Title: Rikki Don't Lose That Number
# We hear you're leaving, that's OK
# I thought our little wild time had just begun
# I guess you kind of scared yourself, you turn and run
# But if you have a change of heart
#
# [Chorus]
# Rikki don't lose that number
# You don't want to call nobody else
# Send it off in a letter to yourself
# Rikki don't lose that number
# It's the only one you own
# You might use it if you feel better
# When you get home
#
# I have a friend in town, he's heard your name
# We can go out driving on Slow Hand Row
# We could stay inside and play games, I don't know
# And you could have a change of heart
#
# [Chorus]
#
# You tell yourself you're not my kind
# But you don't even know your mind
# And you could have a change of heart
#
# [Chorus]
#
#
# After
# -----
# Artist: Steely Dan
# Title: Rikki Don't Lose That Number
# We hear you're leaving, that's OK
# I thought our little wild time had just begun
# I guess you kind of scared yourself, you turn and run
# But if you have a change of heart
#
# Rikki don't lose that number
# You don't want to call nobody else
# Send it off in a letter to yourself
# Rikki don't lose that number
# It's the only one you own
# You might use it if you feel better
# When you get home
#
# I have a friend in town, he's heard your name
# We can go out driving on Slow Hand Row
# We could stay inside and play games, I don't know
# And you could have a change of heart
#
# Rikki don't lose that number
# You don't want to call nobody else
# Send it off in a letter to yourself
# Rikki don't lose that number
# It's the only one you own
# You might use it if you feel better
# When you get home
#
# You tell yourself you're not my kind
# But you don't even know your mind
# And you could have a change of heart
#
# Rikki don't lose that number
# You don't want to call nobody else
# Send it off in a letter to yourself
# Rikki don't lose that number
# It's the only one you own
# You might use it if you feel better
# When you get home

# %% [markdown]
# The above example shows that our function properly remove the chorus indicators from our example song and replaces it with the actual lyrics. Turns out that our function is able to succesfully accomplish this task for 33 of our 87 Steely Dan songs. Unfortunately, there are 4 other songs which have much stranger formattings that I could not work around. As a result, this will only leave us with 83 out of 87 of our Steely Dan songs for training. Though we made the function specifically, for the Steely Dan songs, we might as well run it on the whole dataset to save as many songs as we can. Many of the others follow the same Chorus format, which is the most common of these issues, so we could save a significant amount of records. If it doesn'twork on the songs, then no matter, they will just be deleted in our following step.

# %%
# running function for chorus on entire dataset
dataset = ReplaceChorus(dataset.copy())

# %% [markdown]
# Now that we have fixed what we reasonably can, let's delete all the remaining songs that have these structural placeholders within brackets, since these songs are potentially missing lyrics. After doing so we will print some statistics to measure the change to the dataset.

# %%
dataset = dataset[dataset['text'].str.contains('\[(.*?)\]') == False]
# Out:
# C:\Users\Mitchell\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\strings.py:1954: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %%
# Show statistics
dataset.info()
dataset.describe(include = 'all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47973 entries, 0 to 57649
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   artist  47973 non-null  object
#  1   song    47973 non-null  object
#  2   text    47973 non-null  object
# dtypes: object(3)
# memory usage: 1.5+ MB
#                   artist   song  \
# count              47973  47973
# unique               639  40998
# top     Gordon Lightfoot  Angel
# freq                 183     21
#
#                                                      text
# count                                               47973
# unique                                              47973
# top     Put yourself in my place  \nIf only for a day ...
# freq                                                    1

# %% [markdown]
# #### Removing Additional Comments
#
# Now that we finally addressed the verse placeholders, as best we could, let's move on the next issue with our song lyrics, the extraneous information about the song included in the lyrics. Typically this information is listed in the song between parenthesis, and from what I can tell is most often used to indicate backup vocals, the artist performing the song, and extrneous sounds in the music. None of these are very useful for the model we want to train, so let's try and remove as much as we can. To get an idea of what we are trying to tackle, below are two examples of these types of comments.

# %%
example_1 = dataset.loc[1]
example_2 = dataset.loc[15962]

print('Artist: ' + example_1['artist'])
print('Title: ' + example_1['song'])
print(example_1['text'])
print('Artist: ' + example_2['artist'])
print('Title: ' + example_2['song'])
print(example_2['text'])
# Out:
# Artist: ABBA
# Title: Andante, Andante
# Take it easy with me, please
# Touch me gently like a summer evening breeze
# Take your time, make it slow
# Andante, Andante
# Just let the feeling grow
#
# Make your fingers soft and light
# Let your body be the velvet of the night
# Touch my soul, you know how
# Andante, Andante
# Go slowly with me now
#
# I'm your music
# (I am your music and I am your song)
# I'm your song
# (I am your music and I am your song)
# Play me time and time again and make me strong
# (Play me again 'cause you're making me strong)
# Make me sing, make me sound
# (You make me sing and you make me)
# Andante, Andante
# Tread lightly on my ground
# Andante, Andante
# Oh please don't let me down
#
# There's a shimmer in your eyes
# Like the feeling of a thousand butterflies
# Please don't talk, go on, play
# Andante, Andante
# And let me float away
#
# I'm your music
# (I am your music and I am your song)
# I'm your song
# (I am your music and I am your song)
# Play me time and time again and make me strong
# (Play me again 'cause you're making me strong)
# Make me sing, make me sound
# (You make me sing and you make me)
# Andante, Andante
# Tread lightly on my ground
# Andante, Andante
# Oh please don't let me down
#
# Make me sing, make me sound
# (You make me sing and you make me)
# Andante, Andante
# Tread lightly on my ground
# Andante, Andante
# Oh please don't let me down
# Andante, Andante
# Oh please don't let me down
#
#
# Artist: Phil Collins
# Title: It's Over
# (released as b-side of 'dance into the light' single, 1996)
#
# With a young man, with his heart on his sleeve
# Had the body of a man, and a trust of a child
# He never meant to hurt anybody
#
# But he broke some hearts along the way
#
# Ooh, it's all over
# Ooh, it's all done
# Ooh, it's all over
# Or, has it just begun?
#
# All that he spoke came right from his heart
# Though some had been hurt by the things he had said
# Go walking in the long grass to find his peace
# Sometimes it'd grow so tall he'd lose his way
#
# Ooh, now it's all over
# Ooh, it's all done
# Ooh, it's all over
# Or, has it just begun?
#
# Ooh, it's all over
# Ooh, it's all done
# Ooh, it's all over
# Or, has it just begun?

# %% [markdown]
# Unlike with the bracketed verse placheholders, these comments within parenthesis are not detrimental to the song, so we are going to just remove them without affecting the rest of the lyrics. Below we do just that and display one of the songs from above to show the difference.

# %%
# remove comments/lyrics in parenthesis and brackets (turns out some of these exist over multiple lines)
new_text = []
for indx, record in dataset.iterrows():
    text = record['text']
    pattern = re.compile('\((.*?)\)', re.DOTALL)
    text = re.sub(pattern,'', text)
    pattern = re.compile('\[(.*?)\]', re.DOTALL)
    text = re.sub(pattern,'', text)
    new_text.append(text)

dataset['text'] = new_text

# show example
example_1 = dataset.loc[1]
print('Artist: ' + example_1['artist'])
print('Title: ' + example_1['song'])
print(example_1['text'])
# Out:
# Artist: ABBA
# Title: Andante, Andante
# Take it easy with me, please
# Touch me gently like a summer evening breeze
# Take your time, make it slow
# Andante, Andante
# Just let the feeling grow
#
# Make your fingers soft and light
# Let your body be the velvet of the night
# Touch my soul, you know how
# Andante, Andante
# Go slowly with me now
#
# I'm your music
#
# I'm your song
#
# Play me time and time again and make me strong
#
# Make me sing, make me sound
#
# Andante, Andante
# Tread lightly on my ground
# Andante, Andante
# Oh please don't let me down
#
# There's a shimmer in your eyes
# Like the feeling of a thousand butterflies
# Please don't talk, go on, play
# Andante, Andante
# And let me float away
#
# I'm your music
#
# I'm your song
#
# Play me time and time again and make me strong
#
# Make me sing, make me sound
#
# Andante, Andante
# Tread lightly on my ground
# Andante, Andante
# Oh please don't let me down
#
# Make me sing, make me sound
#
# Andante, Andante
# Tread lightly on my ground
# Andante, Andante
# Oh please don't let me down
# Andante, Andante
# Oh please don't let me down

# %% [markdown]
# #### Removing Extra White Space, Empty Lines, Unwanter Characters, Etc.
#
# Looking at the above ABBA song, you see that there are a lot of cases where we have meaningless white space and empty lines. Some of the whitespace served to break up verse, some is meaningless, and some we accidentally created when removing other unwanted text. Ideally, we would leave in the breaks between verses in the hopes that our model could learn this structural pattern. However, with this being our first language model, we are going for simplicity and instead elect to remove the verse breaks, so the only meaningul structure in each song is a line. Below we remove instances of extended whitespace and remove these extra lines. Afterwords we display the same song as above to show the difference.

# %%
# remove extra whitespace and empty lines
dataset['text'] = dataset['text'].str.replace(' +',' ').str.replace(' \n','\n').str.replace('\n+','\n')

# remove empty line at front of songs
new_text = []
for index, record in dataset.iterrows():
    text = record['text']
    if text[0] == '\n':
        text = text[1:]
    new_text.append(text)
    
# replace text
dataset['text'] = new_text

# %%
# show example
example_1 = dataset.loc[1]
print('Artist: ' + example_1['artist'])
print('Title: ' + example_1['song'])
print(example_1['text'])
# Out:
# Artist: ABBA
# Title: Andante, Andante
# Take it easy with me, please
# Touch me gently like a summer evening breeze
# Take your time, make it slow
# Andante, Andante
# Just let the feeling grow
# Make your fingers soft and light
# Let your body be the velvet of the night
# Touch my soul, you know how
# Andante, Andante
# Go slowly with me now
# I'm your music
# I'm your song
# Play me time and time again and make me strong
# Make me sing, make me sound
# Andante, Andante
# Tread lightly on my ground
# Andante, Andante
# Oh please don't let me down
# There's a shimmer in your eyes
# Like the feeling of a thousand butterflies
# Please don't talk, go on, play
# Andante, Andante
# And let me float away
# I'm your music
# I'm your song
# Play me time and time again and make me strong
# Make me sing, make me sound
# Andante, Andante
# Tread lightly on my ground
# Andante, Andante
# Oh please don't let me down
# Make me sing, make me sound
# Andante, Andante
# Tread lightly on my ground
# Andante, Andante
# Oh please don't let me down
# Andante, Andante
# Oh please don't let me down

# %% [markdown]
# Above we see that we properly removed the extra whitespace from our lyrics and now they have a much simpler and uniform structure. While we are at it, let's go ahead and remove some more unwanted characters from our lyrics. Examples of this include $, \%, _, etc. None of these should hold any meaning, so we might as well get rid of them. Below we print all the unwanted characters and then remove them from our lyrics.

# %%
unwanted_char = string.punctuation.replace('"','').replace("'",'').replace('.','').replace('?','').replace('!','')\
                .replace(',','').replace(':','').replace(';','').replace('-','')

print(unwanted_char)
# Out:
# #$%&()*+/<=>@[\]^_`{|}~

# %%
pattern = '[\\/'+unwanted_char+']'

# remove unwanted characters
dataset['text'] = dataset['text'].str.replace(pattern,'')

# %% [markdown]
# You may notice above that we did not remove certain punctuation from our text. This will become apparent later, but in a nutshell we are going to treat these special characters as special words within each line of each song, since commas, periods, question marks, etc. all carry special meaning to them.

# %% [markdown]
# #### Removing Proper Nouns
#
# Proper nouns carry a lot of meaning in songs, since usually most songs are structured around a single person, couple, or place of interest. However, the specific name of this person is not usually all that important. We could probably swap out the name of the person or place with whatever we like best in most cases and it would work fine (though it helps if the name isn't part of the ryhme in the song). Given this theory and the fact that so many of the distinct words in our dataset are names of people or places, we have decided to just replace all occurences with placeholders.
#
# We have decided to replace all proper names of people with the text "\_\_\_\_". The largest benefit we get from doing this is significantly reducing the size of the distinct words in all our songs. This is not necessary for the Bigram model we will be making, but after som preliminary testing on our neural networks, we pretty much realized that our vocabulary needs to be reduced to ~10,000 distinct words to be managable. We felt performing this replacement was a good way to strict the vocabulary while still maintaining some of the context and information behind these types of words. Furthermore, we figured the user could easily fill in the blanks generated using these placeholder when we generate our own songs. The only major downside that could occur due to this replacement is the potential overlap between certain names and common words. In particular, this could be an issue in titles and for the first words of lines since these are capitlalized. For example, the title "Blue Suede Shoes" would get turned into "\_\_\_\_ \_\_\_\_ Shoes". Hopefully this isn't the case for too many songs, and we may look for examples like this to try and prevent these errors.
#
# Below we check that the placeholders don't exist in our dataset already, and then perform the replacement in the titles and lyrics for each song. We ignore the artist names because we want these to be unique and be retained. Note that we load in external files containing all the words we consider to be valid names of people and places.

# %%
# load in names of people and places
names_file = '../names_n_places/combined_names.txt'
places_file = '../names_n_places/combined_places.txt'

# load names
with open(names_file, 'r', encoding = 'UTF-8') as f:
    text = f.read()
    all_names = text.split('\n')

# load places
with open(places_file, 'r', encoding = 'UTF-8') as f:
    text = f.read()
    all_places = text.split('\n')

# %%
# grab unique words from all song titles and lyrics
unique_words = {}
for index, record in dataset.iterrows():
    title = record['song']
    lyrics = record['text']
    words = title.split(' ') + lyrics.split(' ')
    for word in words:
        try:
            unique_words[word] += 1
        except KeyError:
            unique_words[word] = 1

print("# of unique words in titles and lyrics: {}".format(len(unique_words)))
# Out:
# # of unique words in titles and lyrics: 709585

# %%
# see which of our names are in actually in our dataset and how often
names_in_data = {}
for name in all_names:
    if name in unique_words:
        names_in_data[name] = unique_words[name]
names_in_data = {k: v for k, v in sorted(names_in_data.items(), key=lambda item: item[1], reverse = True)}

print("# of names found in dataset: {}".format(len(names_in_data)))
print("# of words in dataset matching a name: {}".format(sum(names_in_data.values())))
names_in_data
# Out:
# # of names and places found in dataset: 5679
# # of words in dataset matching a name or place: 352273
# {'I': 216028,
#  'The': 9879,
#  'You': 8363,
#  'In': 3327,
#  'Love': 2967,
#  'My': 2937,
#  'God': 2895,
#  'Me': 2440,
#  'Christmas': 2025,
#  'Lord': 1379,
#  'He': 1369,
#  'Oh': 1197,
#  'Be': 1061,
#  'Jesus': 1034,
#  'No': 972,
#  'Do': 907,
#  'So': 887,
#  'She': 880,
#  'Well': 825,
#  'Just': 817,
#  'Like': 816,
#  'Time': 812,
#  'Little': 762,
#  'Man': 751,
#  'Baby': 739,
#  'Down': 716,
#  'Go': 699,
#  'Heart': 670,
#  'King': 609,
#  'Can': 580,
#  'Life': 547,
#  'York': 543,
#  'Good': 539,
#  'Back': 526,
#  'From': 526,
#  'Song': 514,
#  'Day': 510,
#  'Will': 508,
#  'Way': 504,
#  'Night': 488,
#  'Blue': 484,
#  'Not': 473,
#  'Girl': 471,
#  'Heaven': 468,
#  'Sunday': 443,
#  'Black': 441,
#  'Saturday': 403,
#  'See': 400,
#  'Santa': 398,
#  'Say': 398,
#  'Mary': 393,
#  'John': 389,
#  'Miss': 385,
#  'Last': 385,
#  'Long': 377,
#  'Every': 377,
#  'Rock': 373,
#  'Home': 366,
#  'Old': 363,
#  'Johnny': 359,
#  'Boy': 354,
#  'O': 348,
#  'Sweet': 329,
#  'Too': 329,
#  'Tell': 325,
#  'Jack': 322,
#  'More': 316,
#  'Gonna': 309,
#  'Some': 308,
#  'Christ': 294,
#  'Eyes': 293,
#  'Holy': 289,
#  'Hell': 284,
#  'Lady': 275,
#  'Friday': 272,
#  'La': 269,
#  'Dream': 261,
#  'Her': 260,
#  'Queen': 255,
#  'Red': 255,
#  'Music': 252,
#  'Billy': 242,
#  'Sun': 239,
#  'Believe': 237,
#  'Wanna': 236,
#  'Bad': 228,
#  'White': 225,
#  'Street': 224,
#  'Light': 221,
#  'Texas': 219,
#  'Woman': 218,
#  'West': 216,
#  'Earth': 209,
#  'River': 208,
#  'San': 204,
#  'California': 202,
#  'First': 200,
#  'Daddy': 200,
#  'London': 198,
#  'Rain': 194,
#  'Roll': 193,
#  'Or': 191,
#  'Mama': 189,
#  'Green': 188,
#  'Happy': 188,
#  'Ray': 187,
#  'South': 187,
#  'Money': 186,
#  'Jimmy': 185,
#  'Joe': 184,
#  'Moon': 184,
#  'House': 184,
#  'Child': 182,
#  'End': 181,
#  'Beautiful': 174,
#  'Hard': 172,
#  'Great': 170,
#  'Morning': 170,
#  'Monday': 169,
#  'Born': 168,
#  'Kid': 166,
#  'Ever': 166,
#  'Mister': 165,
#  'Free': 164,
#  'Call': 164,
#  'America': 164,
#  'An': 163,
#  'Star': 163,
#  'Young': 162,
#  'Than': 162,
#  'Angel': 162,
#  'East': 159,
#  'Indian': 158,
#  'Georgia': 157,
#  'Forever': 157,
#  'Walk': 156,
#  'Soul': 156,
#  'Angels': 154,
#  'Name': 151,
#  'Hello': 150,
#  'Had': 146,
#  'Son': 146,
#  'Comes': 145,
#  'Kiss': 144,
#  'Rose': 138,
#  'Da': 138,
#  'Fall': 137,
#  'Friend': 137,
#  'Mr': 136,
#  'James': 134,
#  'North': 134,
#  'English': 133,
#  'Head': 130,
#  'Easy': 130,
#  'Summer': 129,
#  'Die': 127,
#  'Sky': 127,
#  'Thy': 126,
#  'Ah': 126,
#  'Train': 126,
#  'French': 125,
#  'El': 123,
#  'Jane': 121,
#  'Sing': 120,
#  'Cadillac': 119,
#  'Na': 118,
#  'Deep': 117,
#  'May': 116,
#  'Hand': 115,
#  'Peter': 115,
#  'Magic': 115,
#  'Midnight': 114,
#  'December': 113,
#  'Place': 113,
#  'Hot': 113,
#  'Prince': 112,
#  'Line': 112,
#  'Sally': 112,
#  'Glory': 111,
#  'Best': 111,
#  'Wild': 111,
#  'April': 110,
#  'Island': 110,
#  'Jah': 110,
#  'Real': 109,
#  'Off': 109,
#  'Paris': 108,
#  'Wake': 108,
#  'Said': 107,
#  'Spirit': 106,
#  'Mine': 105,
#  'Tennessee': 105,
#  'Close': 105,
#  'Captain': 104,
#  'George': 104,
#  'Any': 103,
#  'Charlie': 103,
#  'Power': 103,
#  'Hope': 102,
#  'Golden': 102,
#  'Bob': 102,
#  'Were': 101,
#  'Much': 100,
#  'Find': 100,
#  'Claus': 100,
#  'Water': 98,
#  'Sam': 98,
#  'Sister': 98,
#  'Ni': 98,
#  'Help': 96,
#  'Jim': 96,
#  'Kill': 95,
#  'Then': 95,
#  'Pretty': 95,
#  'Even': 95,
#  'True': 94,
#  'B': 94,
#  'Dixie': 93,
#  'Radio': 92,
#  'Tomorrow': 92,
#  'Merry': 91,
#  'Lay': 91,
#  'Top': 91,
#  'Welcome': 90,
#  'Park': 90,
#  'Bird': 89,
#  'Chance': 88,
#  'Southern': 88,
#  'Ya': 87,
#  'Lee': 86,
#  'Savior': 86,
#  'Has': 85,
#  'Far': 85,
#  'Other': 85,
#  'Jesse': 84,
#  'Stone': 84,
#  'Seven': 83,
#  'Silver': 83,
#  'Kentucky': 82,
#  'De': 82,
#  'Shine': 82,
#  'Jones': 81,
#  'Bill': 81,
#  'Steve': 81,
#  'Brown': 81,
#  'Strange': 80,
#  'Gold': 80,
#  'Ba': 79,
#  'Story': 79,
#  'Doctor': 78,
#  'Perfect': 78,
#  'Hank': 78,
#  'Gypsy': 78,
#  'Bobby': 78,
#  'Frank': 77,
#  'Burn': 77,
#  'Peace': 77,
#  'Louis': 76,
#  'C': 76,
#  'England': 76,
#  'Sunset': 75,
#  'Michael': 75,
#  'Honey': 74,
#  'David': 74,
#  'Alabama': 74,
#  'Shepherd': 73,
#  'Bridge': 73,
#  'Cross': 73,
#  'Hill': 73,
#  'Paul': 73,
#  'Annie': 73,
#  'Slim': 73,
#  'Lucy': 73,
#  'Saint': 73,
#  'Many': 72,
#  'Memphis': 72,
#  'Four': 71,
#  'Lucky': 71,
#  'Louisiana': 70,
#  'Sea': 70,
#  'Kansas': 70,
#  'Barbara': 69,
#  'Diamond': 68,
#  'Chew': 68,
#  'Secret': 68,
#  'E': 67,
#  'Paradise': 67,
#  'Miles': 67,
#  'Saw': 67,
#  'Lie': 67,
#  'Di': 66,
#  'September': 66,
#  'Bang': 66,
#  'Jackson': 65,
#  'China': 65,
#  'Sugar': 65,
#  'Lies': 65,
#  'X': 64,
#  'Lose': 64,
#  'Lake': 64,
#  'Forget': 64,
#  'Grand': 64,
#  'Maria': 63,
#  'Ball': 63,
#  'Elvis': 63,
#  'Bethlehem': 63,
#  'Christian': 63,
#  'Brooklyn': 63,
#  'Number': 63,
#  'Liza': 62,
#  'Lisa': 62,
#  'Pain': 62,
#  'Care': 62,
#  'Lamb': 62,
#  'Wall': 62,
#  'Irish': 62,
#  'Freedom': 62,
#  'Used': 62,
#  'Frankie': 62,
#  'Imma': 62,
#  'Fine': 61,
#  'Papa': 61,
#  'Tom': 61,
#  'Harry': 61,
#  'Matter': 61,
#  'July': 60,
#  'Wonder': 60,
#  'Rio': 59,
#  'Eve': 59,
#  'Low': 58,
#  'Future': 58,
#  'Detroit': 58,
#  'Holiday': 58,
#  'Justice': 58,
#  'Faith': 58,
#  'Louie': 58,
#  'Brother': 57,
#  'Willie': 57,
#  'Promise': 57,
#  'Henry': 57,
#  'Ta': 57,
#  'Grace': 56,
#  'Jean': 55,
#  'June': 55,
#  'Chevy': 55,
#  'Betty': 55,
#  'Rocky': 55,
#  'Guess': 55,
#  'Romeo': 55,
#  'Tuesday': 55,
#  'Yo': 55,
#  'Fat': 55,
#  'Carry': 54,
#  'Sunshine': 54,
#  'D': 54,
#  'Nature': 54,
#  'Venus': 54,
#  'Tommy': 54,
#  'Jerusalem': 54,
#  'Jackie': 53,
#  'Mercy': 53,
#  'Marie': 53,
#  'Candy': 53,
#  'Northern': 53,
#  'Kings': 53,
#  'Million': 53,
#  'Master': 53,
#  'Judas': 52,
#  'Praise': 52,
#  'Robert': 52,
#  'German': 52,
#  'Meet': 52,
#  'Molly': 52,
#  'Winter': 51,
#  'Wings': 51,
#  'Richard': 51,
#  'Easter': 51,
#  'Linda': 51,
#  'Nashville': 51,
#  'Roman': 51,
#  'Oklahoma': 51,
#  'William': 51,
#  'Beat': 50,
#  'Eddie': 50,
#  'Book': 50,
#  'Hannah': 50,
#  'Anna': 50,
#  'Jerry': 50,
#  'Kingdom': 50,
#  'Roses': 49,
#  'Julie': 49,
#  'Moses': 49,
#  'Luck': 49,
#  'Fuck': 49,
#  'Don': 49,
#  'Set': 49,
#  'Part': 49,
#  'Reason': 49,
#  'Truth': 49,
#  'Cat': 49,
#  'Chicago': 49,
#  'Till': 49,
#  'Nice': 49,
#  'Mystery': 49,
#  'Dan': 48,
#  'Snow': 48,
#  'Harlem': 48,
#  'Union': 48,
#  'Apple': 48,
#  'Trust': 48,
#  'Told': 48,
#  'Valley': 47,
#  'Cajun': 47,
#  'Army': 47,
#  'Mike': 47,
#  'Jam': 47,
#  'Miami': 47,
#  'Shadow': 47,
#  'Rainbow': 47,
#  'Jenny': 47,
#  'Van': 47,
#  'Cotton': 47,
#  'Ring': 46,
#  'Rome': 46,
#  'Small': 46,
#  'Early': 46,
#  'Lion': 46,
#  'Spring': 46,
#  'Storm': 46,
#  'Eden': 45,
#  'Jungle': 45,
#  'Soon': 45,
#  'Atlanta': 45,
#  'Beach': 45,
#  'Wayne': 45,
#  'President': 45,
#  'Central': 44,
#  'Smith': 44,
#  'Ann': 44,
#  'Planet': 44,
#  'British': 44,
#  'Yellow': 44,
#  'Hammer': 44,
#  'Judy': 44,
#  'Garden': 44,
#  'Sarah': 44,
#  'Butterfly': 44,
#  'Miracle': 44,
#  'Mo': 43,
#  'Sunny': 43,
#  'Sue': 43,
#  'Hang': 43,
#  'Hole': 43,
#  'Avenue': 43,
#  'Adam': 43,
#  'Pop': 43,
#  'Robin': 43,
#  'Washington': 42,
#  'Joy': 42,
#  'Martin': 42,
#  'Memory': 42,
#  'Bay': 42,
#  'Hallelujah': 42,
#  'October': 42,
#  'Ten': 42,
#  'Glass': 42,
#  'J': 42,
#  'Vegas': 42,
#  'Such': 42,
#  'Guy': 41,
#  'Gets': 41,
#  'Los': 41,
#  'Beauty': 41,
#  'Key': 41,
#  'Mona': 40,
#  'Kingston': 40,
#  'Boom': 40,
#  'Most': 40,
#  'Mark': 40,
#  'General': 39,
#  'Heard': 39,
#  'Catch': 39,
#  'Ho': 39,
#  'Las': 39,
#  'Bright': 39,
#  'Mack': 39,
#  'Al': 39,
#  'Ruby': 39,
#  'Car': 39,
#  'Ocean': 39,
#  'Box': 39,
#  'Paper': 39,
#  'Bear': 38,
#  'Jamaica': 38,
#  'Lincoln': 38,
#  'Virginia': 38,
#  'Wednesday': 38,
#  'Bless': 38,
#  'Denver': 38,
#  'Super': 38,
#  'August': 38,
#  'Ole': 38,
#  'Dawn': 38,
#  'Alice': 38,
#  'Dallas': 37,
#  'Cindy': 37,
#  'Darling': 37,
#  'L': 37,
#  'Strong': 37,
#  'Temple': 37,
#  'Cherry': 37,
#  'Coast': 37,
#  'Walls': 37,
#  'Bonnie': 37,
#  'Leroy': 37,
#  'Beer': 37,
#  'Main': 37,
#  'State': 36,
#  'Hero': 36,
#  'Bo': 36,
#  'Manhattan': 36,
#  'Rat': 36,
#  'Western': 36,
#  'Cinderella': 36,
#  'Edge': 36,
#  'Chelsea': 36,
#  'Kitty': 36,
#  'Mane': 35,
#  'Fell': 35,
#  'Iron': 35,
#  'Bar': 35,
#  'Carolina': 35,
#  'Lot': 35,
#  'Lou': 35,
#  'November': 35,
#  'Pan': 35,
#  'Lovely': 35,
#  'Saviour': 34,
#  'Steel': 34,
#  'Tear': 34,
#  'Jet': 34,
#  'F': 34,
#  'Houston': 34,
#  'Prayer': 34,
#  'Ive': 34,
#  'Autumn': 34,
#  'Rocket': 34,
#  'Lang': 33,
#  'Marilyn': 33,
#  'Thunder': 33,
#  'Kong': 33,
#  'Mercedes': 33,
#  'Corner': 33,
#  'Grey': 33,
#  'Midas': 33,
#  'Penny': 33,
#  'Desire': 32,
#  'Tall': 32,
#  'Brand': 32,
#  'Killer': 32,
#  'Pay': 32,
#  'Donna': 31,
#  'Doll': 31,
#  'Amazing': 31,
#  'Flame': 31,
#  'Puerto': 31,
#  'Fair': 31,
#  'Montana': 31,
#  'Pa': 31,
#  'Babe': 31,
#  'Sin': 31,
#  'Fallen': 31,
#  'Barbar': 31,
#  'Calls': 30,
#  'Samson': 30,
#  'Ronnie': 30,
#  'Pick': 30,
#  'Count': 30,
#  'Buddy': 30,
#  'Wolf': 30,
#  'Caroline': 30,
#  'Loose': 30,
#  'Cole': 30,
#  'Delta': 30,
#  'Very': 29,
#  'Pray': 29,
#  'Alley': 29,
#  'Creek': 29,
#  'Chain': 29,
#  'Evening': 29,
#  'Ma': 29,
#  'Nicki': 29,
#  'Rainy': 29,
#  'Sail': 29,
#  'Special': 29,
#  'Jordan': 29,
#  'Precious': 29,
#  'Zion': 29,
#  'Royal': 29,
#  'Album': 29,
#  'Colorado': 28,
#  'Church': 28,
#  'Sunrise': 28,
#  'Castle': 28,
#  'Jo': 28,
#  'Ha': 28,
#  'Pleasure': 28,
#  'Katy': 28,
#  'Caribbean': 28,
#  'Charles': 28,
#  'Suzie': 28,
#  'Else': 28,
#  'Universe': 28,
#  'Melody': 28,
#  'Williams': 28,
#  'Yankee': 28,
#  'Twilight': 28,
#  'Wave': 28,
#  'Romance': 28,
#  'Boston': 28,
#  'Silence': 28,
#  'Law': 27,
#  'Beverly': 27,
#  'Lil': 27,
#  'Madison': 27,
#  'Rosie': 27,
#  'Bell': 27,
#  'Luther': 27,
#  'Dennis': 27,
#  'Yang': 27,
#  'Willy': 27,
#  'Cherokee': 27,
#  'Rise': 27,
#  'Carol': 27,
#  'Francisco': 27,
#  'Havana': 27,
#  'Bet': 27,
#  'France': 27,
#  'Emily': 27,
#  'Soldier': 27,
#  'Virgin': 27,
#  'Point': 27,
#  'Art': 26,
#  'Hall': 26,
#  'Wu': 26,
#  'St': 26,
#  'Holding': 26,
#  'Phil': 26,
#  'Mars': 26,
#  'Hills': 26,
#  'Nuh': 26,
#  'Flowers': 26,
#  'Cash': 26,
#  'Cisco': 26,
#  'Jersey': 26,
#  'Joan': 26,
#  'Rhythm': 26,
#  'Coney': 26,
#  'Madonna': 26,
#  'Diamonds': 26,
#  'Both': 26,
#  'Cleveland': 26,
#  'Brave': 26,
#  'Bruce': 26,
#  'Gift': 25,
#  'Maggie': 25,
#  'Rage': 25,
#  'Alouette': 25,
#  'Crow': 25,
#  'Independence': 25,
#  'Benz': 25,
#  'Speed': 25,
#  'Wolfe': 25,
#  'Kisses': 25,
#  'Heavenly': 25,
#  'Seasons': 25,
#  'Pink': 25,
#  'Freddy': 25,
#  'Happiness': 25,
#  'Harley': 25,
#  'Florida': 25,
#  'Liberty': 25,
#  'Canada': 25,
#  'Driver': 25,
#  'Danny': 25,
#  'Waltz': 24,
#  'Sandy': 24,
#  'Lily': 24,
#  'Almighty': 24,
#  'Joey': 24,
#  'Ko': 24,
#  'Tony': 24,
#  'Minne': 24,
#  'Velvet': 24,
#  'Arlo': 24,
#  'M': 24,
#  'Tiger': 24,
#  'Anger': 24,
#  'Clash': 24,
#  'Ford': 24,
#  'Christopher': 24,
#  'Gates': 24,
#  'Lone': 24,
#  'Christie': 24,
#  'Fox': 24,
#  'Cain': 24,
#  'Rebel': 24,
#  'Caesar': 24,
#  'Juliet': 24,
#  'Fields': 24,
#  'Arthur': 23,
#  'Gloria': 23,
#  'Thomas': 23,
#  'Stuck': 23,
#  'Boss': 23,
#  'Danger': 23,
#  'Zevon': 23,
#  'Mi': 23,
#  'Wise': 23,
#  'Dakota': 23,
#  'Carter': 23,
#  'Flash': 23,
#  'Karma': 23,
#  'Le': 23,
#  'Te': 23,
#  'Joseph': 23,
#  'Chris': 23,
#  'Foot': 23,
#  'Bama': 23,
#  'Fred': 23,
#  'Rich': 22,
#  'Hong': 22,
#  'Zero': 22,
#  'Anthem': 22,
#  'Africa': 22,
#  'Brain': 22,
#  'Rita': 22,
#  'Wedding': 22,
#  'Allan': 22,
#  'Win': 22,
#  'Company': 22,
#  'Famous': 22,
#  'Andy': 22,
#  'Pet': 22,
#  'Thompson': 22,
#  'Common': 22,
#  'Egypt': 22,
#  'Mamma': 22,
#  'Nation': 22,
#  'Ireland': 22,
#  'Tim': 22,
#  'Jay': 22,
#  'Marry': 22,
#  'Square': 22,
#  'Susie': 22,
#  'Roger': 22,
#  'Cupid': 22,
#  'Davis': 22,
#  'Holly': 22,
#  'Warren': 22,
#  'March': 22,
#  'Blessed': 22,
#  'Fish': 21,
#  'Major': 21,
#  'Pete': 21,
#  'Ry': 21,
#  'Sand': 21,
#  'Fancy': 21,
#  'Grass': 21,
#  'Imagine': 21,
#  'Raven': 21,
#  'Mac': 21,
#  'Israel': 21,
#  'Fortune': 21,
#  'Princess': 21,
#  'Journey': 21,
#  'None': 21,
#  'Coke': 21,
#  'Abigail': 21,
#  'Louise': 21,
#  'Destiny': 21,
#  'Pack': 21,
#  'Rush': 21,
#  'Franklin': 21,
#  'Sioux': 21,
#  'Crown': 21,
#  'Strawberry': 21,
#  'Flower': 21,
#  'Battle': 21,
#  'Dean': 21,
#  'Gemini': 21,
#  'Funk': 21,
#  'Fantasy': 20,
#  'Jeanie': 20,
#  'Sean': 20,
#  'Jeff': 20,
#  'Hawaii': 20,
#  'Ye': 20,
#  'Dave': 20,
#  'Junior': 20,
#  'Pie': 20,
#  'Marley': 20,
#  'Brady': 20,
#  'Games': 20,
#  'Indiana': 20,
#  'Lark': 20,
#  'Delilah': 20,
#  'Les': 20,
#  'Emanuel': 20,
#  'Mardi': 20,
#  'Sahara': 20,
#  'Tha': 20,
#  'Chuck': 20,
#  'Juan': 20,
#  'Carrie': 20,
#  'Medley': 20,
#  'Eternal': 20,
#  'Pride': 20,
#  'Hood': 20,
#  'Field': 20,
#  'Lo': 20,
#  'Daily': 20,
#  'Ricky': 20,
#  'Dick': 20,
#  'Ivy': 20,
#  'Kelly': 20,
#  'Ying': 20,
#  'Johnnie': 20,
#  'Albert': 20,
#  'Roller': 20,
#  'Cha': 20,
#  'Rusty': 20,
#  'Gospel': 19,
#  'Mickey': 19,
#  'Christians': 19,
#  'Dare': 19,
#  'Ed': 19,
#  'Passion': 19,
#  'Donald': 19,
#  'Krishna': 19,
#  'Belle': 19,
#  'Tokyo': 19,
#  'Tin': 19,
#  'Lili': 19,
#  'Rye': 19,
#  'Crystal': 19,
#  'Canaan': 19,
#  'Coupe': 19,
#  'Rudolph': 19,
#  'Allah': 19,
#  'Spiritual': 19,
#  'Arizona': 19,
#  'Rider': 19,
#  'Tudo': 19,
#  'Daniel': 19,
#  'Ron': 19,
#  'Messiah': 19,
#  'Dreamer': 19,
#  'Fame': 19,
#  'Asian': 19,
#  'Frisco': 19,
#  'Maine': 19,
#  'Kanye': 19,
#  'Crash': 19,
#  'Read': 19,
#  'Pour': 19,
#  'Boots': 19,
#  'Nellie': 19,
#  'Silly': 19,
#  'Mount': 19,
#  'Race': 19,
#  'Pope': 19,
#  'Alberta': 19,
#  'Nine': 19,
#  'Grab': 19,
#  'Buffet': 18,
#  'Nick': 18,
#  'Whisper': 18,
#  'Peggy': 18,
#  'Swan': 18,
#  'Pearl': 18,
#  'Earl': 18,
#  'Sonny': 18,
#  'Adore': 18,
#  'Sir': 18,
#  'Columbus': 18,
#  'Amy': 18,
#  'Jennifer': 18,
#  'Bronx': 18,
#  'Perry': 18,
#  'Wood': 18,
#  'Deal': 18,
#  'Rhode': 18,
#  'Gang': 18,
#  'Bee': 18,
#  'Romans': 18,
#  'Mae': 18,
#  'Marlon': 17,
#  'Pleasant': 17,
#  'Chair': 17,
#  'Price': 17,
#  'Wilson': 17,
#  'Bwana': 17,
#  'Pepsi': 17,
#  'Oscar': 17,
#  'Russia': 17,
#  'Johnson': 17,
#  'Divine': 17,
#  'Berlin': 17,
#  'Cloud': 17,
#  'Bone': 17,
#  'Short': 17,
#  'Eagle': 17,
#  'Jehovah': 17,
#  'Domino': 17,
#  'Toy': 17,
#  'Chicken': 17,
#  'Natural': 17,
#  'Comfort': 17,
#  'Mess': 17,
#  'Lula': 17,
#  'Minnie': 17,
#  'Mile': 17,
#  'Nova': 17,
#  'Bentley': 17,
#  'Alien': 17,
#  'Gary': 17,
#  'January': 17,
#  'Bush': 17,
#  'Season': 17,
#  'Grove': 17,
#  'Otis': 17,
#  'Doo': 17,
#  'Fate': 17,
#  'Candace': 16,
#  'Missy': 16,
#  'Shirley': 16,
#  'Jolly': 16,
#  'Paso': 16,
#  'Page': 16,
#  'Kinda': 16,
#  'Emperor': 16,
#  'Waters': 16,
#  'Neon': 16,
#  'Shorty': 16,
#  'Andrew': 16,
#  'Erie': 16,
#  'Cinnamon': 16,
#  'Nancy': 16,
#  'Stomp': 16,
#  'Portland': 16,
#  'Avalon': 16,
#  'Noah': 16,
#  'Phoenix': 16,
#  'Dee': 16,
#  'Salt': 16,
#  'Cali': 16,
#  'Ran': 16,
#  'Orange': 16,
#  'Lenny': 16,
#  'Bon': 16,
#  'Amen': 16,
#  'Bus': 16,
#  'Baker': 16,
#  'R': 16,
#  'Anne': 16,
#  'Hop': 16,
#  'Mood': 16,
#  'Culver': 16,
#  'Waylon': 16,
#  'Fort': 16,
#  'Bridges': 16,
#  'Buzz': 16,
#  'Duke': 16,
#  'Bessie': 16,
#  'Dong': 15,
#  'Daniels': 15,
#  'Goldie': 15,
#  'Stevie': 15,
#  'Katie': 15,
#  'Bow': 15,
#  'Simon': 15,
#  'Frost': 15,
#  'Carson': 15,
#  'Arabian': 15,
#  'Jazz': 15,
#  'Rue': 15,
#  'Amish': 15,
#  'Ace': 15,
#  'Kay': 15,
#  'Jefferson': 15,
#  'Harder': 15,
#  'Billie': 15,
#  'Court': 15,
#  'Arnold': 15,
#  'Vanna': 15,
#  'Less': 15,
#  'Esta': 15,
#  'Eric': 15,
#  'Mercury': 15,
#  ...}

# %%
# see which of our places are in actually in our dataset and how often
places_in_data = {}
for place in all_places:
    if place in unique_words:
        places_in_data[place] = unique_words[place]
places_in_data = {k: v for k, v in sorted(places_in_data.items(), key=lambda item: item[1], reverse = True)}

print("# of places found in dataset: {}".format(len(places_in_data)))
print("# of words in dataset matching a place: {}".format(sum(places_in_data.values())))
places_in_data
# Out:
# # of places found in dataset: 1235
# # of words in dataset matching a place: 15593
# {'We': 1280,
#  'Man': 751,
#  'King': 609,
#  'York': 543,
#  'Mary': 393,
#  'Hollywood': 249,
#  'Texas': 219,
#  'San': 204,
#  'California': 202,
#  'London': 198,
#  'Green': 188,
#  'Star': 163,
#  'Young': 162,
#  'Georgia': 157,
#  'Mountain': 131,
#  'Mississippi': 126,
#  'Cadillac': 119,
#  'Paris': 108,
#  'Tennessee': 105,
#  'George': 104,
#  'Hope': 102,
#  'Golden': 102,
#  'Same': 98,
#  'Welcome': 90,
#  'Southern': 88,
#  'Lee': 86,
#  'Kentucky': 82,
#  'Middle': 81,
#  'Ba': 79,
#  'Orleans': 78,
#  'Sunset': 75,
#  'Alabama': 74,
#  'David': 74,
#  'Paul': 73,
#  'Memphis': 72,
#  'Kansas': 70,
#  'Louisiana': 70,
#  'Paradise': 67,
#  'Jackson': 65,
#  'China': 65,
#  'Bethlehem': 63,
#  'Brooklyn': 63,
#  'Wall': 62,
#  'Justice': 58,
#  'Detroit': 58,
#  'Holiday': 58,
#  'Jerusalem': 54,
#  'Northern': 53,
#  'Linda': 51,
#  'Nashville': 51,
#  'Oklahoma': 51,
#  'Anna': 50,
#  'Broadway': 50,
#  'Chicago': 49,
#  'Nice': 49,
#  'Union': 48,
#  'Valley': 47,
#  'Van': 47,
#  'Miami': 47,
#  'Spring': 46,
#  'Rome': 46,
#  'Eden': 45,
#  'Atlanta': 45,
#  'Wayne': 45,
#  'Central': 44,
#  'Mexico': 44,
#  'Babylon': 43,
#  'Washington': 42,
#  'Martin': 42,
#  'Bay': 42,
#  'Kingston': 40,
#  'Mack': 39,
#  'Ocean': 39,
#  'Bright': 39,
#  'Ho': 39,
#  'Alice': 38,
#  'Jamaica': 38,
#  'August': 38,
#  'Lincoln': 38,
#  'Virginia': 38,
#  'Bear': 38,
#  'Denver': 38,
#  'Coast': 37,
#  'Temple': 37,
#  'Dallas': 37,
#  'Atlantic': 37,
#  'Western': 36,
#  'Bo': 36,
#  'Manhattan': 36,
#  'Chelsea': 36,
#  'Moscow': 35,
#  'Bar': 35,
#  'Carolina': 35,
#  'Houston': 34,
#  'Mercedes': 33,
#  'Montana': 31,
#  'Donna': 31,
#  'Delta': 30,
#  'Jordan': 29,
#  'Zion': 29,
#  'Sunrise': 28,
#  'Gulf': 28,
#  'Katy': 28,
#  'Boston': 28,
#  'Williams': 28,
#  'Colorado': 28,
#  'Queens': 27,
#  'France': 27,
#  'Madison': 27,
#  'Bell': 27,
#  'Beverly': 27,
#  'Dennis': 27,
#  'Havana': 27,
#  'Cleveland': 26,
#  'Florida': 25,
#  'Liberty': 25,
#  'Independence': 25,
#  'Canada': 25,
#  'Gates': 24,
#  'Center': 24,
#  'Sandy': 24,
#  'Bama': 23,
#  'Ireland': 22,
#  'Thompson': 22,
#  'Anthem': 22,
#  'Davis': 22,
#  'Holly': 22,
#  'Egypt': 22,
#  'Friendly': 22,
#  'Warren': 22,
#  'Tonk': 22,
#  'Spain': 22,
#  'Strawberry': 21,
#  'Israel': 21,
#  'Franklin': 21,
#  'Ye': 20,
#  'Buffalo': 20,
#  'Pacific': 20,
#  'Brady': 20,
#  'Hawaii': 20,
#  'Indiana': 20,
#  'Rye': 19,
#  'Arizona': 19,
#  'Maine': 19,
#  'Tokyo': 19,
#  'Crystal': 19,
#  'Kanye': 19,
#  'Niagara': 19,
#  'Race': 19,
#  'Frisco': 19,
#  'Needles': 19,
#  'Dagenham': 19,
#  'Alberta': 19,
#  'Bury': 18,
#  'Pearl': 18,
#  'Belfast': 18,
#  'Bronx': 18,
#  'Perry': 18,
#  'Columbus': 18,
#  'Eagle': 17,
#  'Honda': 17,
#  'Fate': 17,
#  'Berlin': 17,
#  'Wilson': 17,
#  'Gary': 17,
#  'Grove': 17,
#  'Ohio': 17,
#  'Mission': 17,
#  'Bend': 17,
#  'Russia': 17,
#  'Price': 17,
#  'Page': 16,
#  'Amsterdam': 16,
#  'Orange': 16,
#  'Erie': 16,
#  'Portland': 16,
#  'Shirley': 16,
#  'Riverside': 16,
#  'Nancy': 16,
#  'Rodeo': 16,
#  'Phoenix': 16,
#  'Baker': 16,
#  'Cali': 16,
#  'Marshall': 15,
#  'Hudson': 15,
#  'Savannah': 15,
#  'Dublin': 15,
#  'Bow': 15,
#  'Jefferson': 15,
#  'Buy': 15,
#  'Carson': 15,
#  'Arnold': 15,
#  'Roy': 15,
#  'Minnesota': 14,
#  'Austin': 14,
#  'Mason': 14,
#  'Worth': 14,
#  'Howard': 14,
#  'Scott': 14,
#  'Taylor': 14,
#  'Crawford': 14,
#  'Halfway': 14,
#  'Birmingham': 14,
#  'Blackpool': 14,
#  'Vietnam': 13,
#  'Monroe': 13,
#  'Michigan': 13,
#  'Charlotte': 13,
#  'Clifton': 13,
#  'Jupiter': 13,
#  'Sale': 13,
#  'Australia': 13,
#  'Clyde': 13,
#  'Japan': 13,
#  'Pittsburgh': 13,
#  'Chattanooga': 13,
#  'Tea': 13,
#  'Germany': 13,
#  'Alaska': 12,
#  'Illinois': 12,
#  'Duquesne': 12,
#  'Galway': 12,
#  'Robinson': 12,
#  'Post': 12,
#  'Rivers': 12,
#  'Store': 12,
#  'Surprise': 12,
#  'Tupelo': 12,
#  'Tulsa': 12,
#  'Cuba': 12,
#  'Emerald': 12,
#  'Gray': 12,
#  'Brick': 12,
#  'Dorado': 12,
#  'Marvin': 12,
#  'Harvest': 12,
#  'Lakes': 12,
#  'Pennsylvania': 12,
#  'Elizabeth': 12,
#  'Lodi': 12,
#  'Vienna': 11,
#  'Oxford': 11,
#  'Nelson': 11,
#  'Tijuana': 11,
#  'Sparks': 11,
#  'Derby': 11,
#  'Italy': 11,
#  'Angeles': 11,
#  'Baltimore': 11,
#  'Gulfport': 11,
#  'Topeka': 11,
#  'India': 11,
#  'Seattle': 11,
#  'Seminole': 11,
#  'Baghdad': 11,
#  'Amarillo': 10,
#  'Santana': 10,
#  'Clark': 10,
#  'Napoleon': 10,
#  'Marina': 10,
#  'Utah': 10,
#  'Normal': 10,
#  'Mexicali': 10,
#  'Hurricane': 10,
#  'Garfield': 10,
#  'Salem': 10,
#  'Neptune': 10,
#  'Brighton': 10,
#  'College': 10,
#  'Jericho': 10,
#  'Cumberland': 10,
#  'Wabash': 10,
#  'Kandy': 10,
#  'Savage': 9,
#  'Sydney': 9,
#  'Victoria': 9,
#  'Magnolia': 9,
#  'Whitney': 9,
#  'Carnegie': 9,
#  'Lynn': 9,
#  'Vas': 9,
#  'Waterloo': 9,
#  'Rotterdam': 9,
#  'Norman': 9,
#  'Kathleen': 9,
#  'Ramona': 9,
#  'Shannon': 9,
#  'Chili': 9,
#  'Allen': 9,
#  'Gilbert': 9,
#  'Canyon': 9,
#  'Turner': 9,
#  'Celebration': 9,
#  'Marlboro': 9,
#  'Trooper': 9,
#  'Pale': 9,
#  'Alma': 9,
#  'Malibu': 9,
#  'Bishop': 9,
#  'Montgomery': 9,
#  'Murphy': 9,
#  'Winston': 9,
#  'Roosevelt': 9,
#  'Bilbao': 9,
#  'Clay': 9,
#  'Shanghai': 9,
#  'Berkeley': 8,
#  'Hollis': 8,
#  'Wichita': 8,
#  'Philadelphia': 8,
#  'Camden': 8,
#  'Oakland': 8,
#  'Vera': 8,
#  'Augusta': 8,
#  'Manzanillo': 8,
#  'Mao': 8,
#  'Fountain': 8,
#  'Evans': 8,
#  'Stanley': 8,
#  'Dixon': 8,
#  'Arkansas': 8,
#  'Miranda': 8,
#  'Haiti': 8,
#  'Knoxville': 8,
#  'Eastern': 8,
#  'Arab': 8,
#  'Liverpool': 8,
#  'Omaha': 8,
#  'Laredo': 8,
#  'Compton': 8,
#  'Sullivan': 8,
#  'Loveland': 8,
#  'Sur': 8,
#  'Gibraltar': 8,
#  'Charleston': 8,
#  'Livingston': 8,
#  'Nassau': 7,
#  'Eldorado': 7,
#  'Saginaw': 7,
#  'Vincent': 7,
#  'Cork': 7,
#  'Randolph': 7,
#  'Dillon': 7,
#  'Plymouth': 7,
#  'Honolulu': 7,
#  'Mustang': 7,
#  'Amos': 7,
#  'Hoover': 7,
#  'Macon': 7,
#  'Hickory': 7,
#  'Ontario': 7,
#  'Leon': 7,
#  'Stuart': 7,
#  'Walden': 7,
#  'Missouri': 7,
#  'Enid': 7,
#  'Churchill': 7,
#  'Middletown': 7,
#  'Springs': 7,
#  'Edna': 7,
#  'Rutherford': 7,
#  'Woodstock': 7,
#  'Yukon': 7,
#  'Waco': 7,
#  'Thames': 7,
#  'Peculiar': 7,
#  'Walker': 7,
#  'Mobile': 7,
#  'Morocco': 7,
#  'Toronto': 7,
#  'Forest': 7,
#  'Oregon': 6,
#  'Ward': 6,
#  'Louisville': 6,
#  'Clover': 6,
#  'Butler': 6,
#  'Spencer': 6,
#  'Enoch': 6,
#  'Scarborough': 6,
#  'Lancashire': 6,
#  'Castro': 6,
#  'Ende': 6,
#  'Duncan': 6,
#  'Beacon': 6,
#  'Nebraska': 6,
#  'Irving': 6,
#  'Newcastle': 6,
#  'Sharon': 6,
#  'Quebec': 6,
#  'Ashland': 6,
#  'Albuquerque': 6,
#  'Ridge': 6,
#  'Granada': 6,
#  'Tucker': 6,
#  'Norfolk': 6,
#  'Troy': 6,
#  'Milwaukee': 6,
#  'Massachusetts': 6,
#  'Antique': 6,
#  'Panama': 6,
#  'Folsom': 6,
#  'Powell': 6,
#  'Marion': 6,
#  'Rogers': 6,
#  'Reunion': 5,
#  'Charlton': 5,
#  'Hamlet': 5,
#  'Ascension': 5,
#  'Kermit': 5,
#  'Vancouver': 5,
#  'Newman': 5,
#  'Kobe': 5,
#  'Chico': 5,
#  'Dali': 5,
#  'Berkley': 5,
#  'Boulder': 5,
#  'Kita': 5,
#  'Columbia': 5,
#  'Leo': 5,
#  'Spokane': 5,
#  'Hiroshima': 5,
#  'Imperial': 5,
#  'Moron': 5,
#  'Mitchell': 5,
#  'Sunnyside': 5,
#  'Cary': 5,
#  'Lloyd': 5,
#  'Turkey': 5,
#  'Milo': 5,
#  'Goodyear': 5,
#  'Derry': 5,
#  'Pontiac': 5,
#  'Terrace': 5,
#  'Humble': 5,
#  'Brazil': 5,
#  'Barcelona': 5,
#  'Burke': 5,
#  'Wisconsin': 5,
#  'Pool': 5,
#  'Cyprus': 5,
#  'Split': 5,
#  'Leeds': 5,
#  'Superior': 5,
#  'Richmond': 5,
#  'Cheshire': 5,
#  'Flanders': 5,
#  'Gay': 5,
#  'Geneva': 5,
#  'Florence': 5,
#  'Venice': 5,
#  'Springfield': 5,
#  'Brush': 5,
#  'Mayo': 5,
#  'Southland': 5,
#  'Sandwich': 4,
#  'Pierre': 4,
#  'Albany': 4,
#  'Lawrence': 4,
#  'Clinton': 4,
#  'Whitman': 4,
#  'Male': 4,
#  'Harlan': 4,
#  'Essex': 4,
#  'Trinidad': 4,
#  'Irvine': 4,
#  'Sheffield': 4,
#  'Tipperary': 4,
#  'Swords': 4,
#  'Bristol': 4,
#  'Athabasca': 4,
#  'Rochelle': 4,
#  'Edison': 4,
#  'Pompey': 4,
#  'Huddersfield': 4,
#  'Greenwich': 4,
#  'Helena': 4,
#  'Aztec': 4,
#  'Gateway': 4,
#  'Harvard': 4,
#  'Moss': 4,
#  'Sherman': 4,
#  'Fargo': 4,
#  'Oriental': 4,
#  'Hun': 4,
#  'Carroll': 4,
#  'Natchez': 4,
#  'Cheyenne': 4,
#  'Reading': 4,
#  'Chile': 4,
#  'Triangle': 4,
#  'Galveston': 4,
#  'University': 4,
#  'Quincy': 4,
#  'Decatur': 4,
#  'Cody': 4,
#  'Conway': 4,
#  'Rosetta': 4,
#  'Northumberland': 4,
#  'Hampton': 4,
#  'Aubrey': 4,
#  'Linwood': 4,
#  'Leicester': 4,
#  'Palestine': 4,
#  'Denmark': 4,
#  'Cypress': 4,
#  'Emmett': 4,
#  'Bakersfield': 4,
#  'Blackhawk': 4,
#  'Argentina': 4,
#  'Lower': 4,
#  'Avondale': 4,
#  'Reno': 4,
#  'Davidson': 4,
#  'Maryland': 4,
#  'Mandeville': 4,
#  'Windsor': 3,
#  'Tucson': 3,
#  'Como': 3,
#  'Beverley': 3,
#  'Pocahontas': 3,
#  'Orlando': 3,
#  'Roma': 3,
#  'Sweden': 3,
#  'Nicaragua': 3,
#  'Wells': 3,
#  'Sycamore': 3,
#  'Tracy': 3,
#  'Tallahassee': 3,
#  'Hov': 3,
#  'Greece': 3,
#  'Yorkshire': 3,
#  'Tampa': 3,
#  'Idaho': 3,
#  'Greensboro': 3,
#  'Butterworth': 3,
#  'Lexington': 3,
#  'Moore': 3,
#  'Jacksonville': 3,
#  'Craig': 3,
#  'Holladay': 3,
#  'Malone': 3,
#  'Iraq': 3,
#  'Wyoming': 3,
#  'Robbins': 3,
#  'Metropolis': 3,
#  'Republic': 3,
#  'Warsaw': 3,
#  'Belmont': 3,
#  'Rigby': 3,
#  'Upper': 3,
#  'Bimbo': 3,
#  'Fletcher': 3,
#  'Hampstead': 3,
#  'Gibson': 3,
#  'Munich': 3,
#  'Shreveport': 3,
#  'Saga': 3,
#  'Holland': 3,
#  'Battlefield': 3,
#  'Topanga': 3,
#  'Dover': 3,
#  'Wicklow': 3,
#  'Delaware': 3,
#  'Centre': 3,
#  'Caledonia': 3,
#  'Stuttgart': 3,
#  'Raleigh': 3,
#  'Kent': 3,
#  'Dalai': 3,
#  'Lebanon': 3,
#  'Morris': 3,
#  'Murray': 3,
#  'Midway': 3,
#  'Hewlett': 3,
#  'Evergreen': 3,
#  'Byron': 3,
#  'Brits': 3,
#  'Brandenburg': 3,
#  'Sid': 3,
#  'Gore': 3,
#  'Glasgow': 3,
#  'Smithers': 3,
#  'Graham': 3,
#  'Southside': 3,
#  'Monterey': 3,
#  'Toulouse': 3,
#  'Copenhagen': 3,
#  'Johnstown': 3,
#  'Jasper': 3,
#  'Yarmouth': 3,
#  'Singapore': 3,
#  'Luce': 3,
#  'Globe': 3,
#  'Milton': 3,
#  'Indianapolis': 3,
#  'Mesa': 3,
#  'Nan': 3,
#  'Niles': 3,
#  'Forbes': 3,
#  'Winters': 3,
#  'Manchester': 3,
#  'Porter': 3,
#  'Southampton': 3,
#  'Johannesburg': 3,
#  'Eugene': 3,
#  'Abilene': 3,
#  'Tame': 3,
#  'Burma': 3,
#  'Ethiopia': 3,
#  'Adams': 3,
#  'Dudley': 3,
#  'Eunice': 3,
#  'Mandalay': 3,
#  'Madrid': 3,
#  'Hazard': 3,
#  'Aurora': 3,
#  'Cedartown': 3,
#  'Wright': 3,
#  'Adrian': 3,
#  'Chesapeake': 3,
#  'Dalton': 3,
#  'Calgary': 3,
#  'Hartford': 3,
#  'Nevada': 3,
#  'Brent': 3,
#  'Isabel': 3,
#  'Tyler': 3,
#  'Pomona': 3,
#  'Anthony': 3,
#  'Newton': 3,
#  'Speedway': 3,
#  'McKenzie': 3,
#  'Lorca': 3,
#  'Lamia': 3,
#  'Bath': 3,
#  'Shenandoah': 3,
#  'Redding': 3,
#  'Sal': 3,
#  'Waimanalo': 3,
#  'Devon': 3,
#  'Garland': 2,
#  'Aberdeen': 2,
#  'Lai': 2,
#  'Mecca': 2,
#  'Barbados': 2,
#  'Batman': 2,
#  'Tobago': 2,
#  'Kokomo': 2,
#  'Balboa': 2,
#  'Scarsdale': 2,
#  'Kensington': 2,
#  'Belgium': 2,
#  'Cologne': 2,
#  'Surabaya': 2,
#  'Casablanca': 2,
#  'Austria': 2,
#  'Revere': 2,
#  'Destin': 2,
#  'Marathon': 2,
#  'Odessa': 2,
#  'Pecos': 2,
#  'Ada': 2,
#  'Crockett': 2,
#  'Dunn': 2,
#  'Bati': 2,
#  'Kaya': 2,
#  'Noble': 2,
#  'Cairo': 2,
#  'Cascades': 2,
#  'Winona': 2,
#  'Preston': 2,
#  'Bryant': 2,
#  'Tara': 2,
#  'Grafton': 2,
#  'Juarez': 2,
#  'Collins': 2,
#  'Lennox': 2,
#  'Blaine': 2,
#  'Sarajevo': 2,
#  'Sacramento': 2,
#  'Americana': 2,
#  'Bermuda': 2,
#  'Bohemia': 2,
#  'Lindsay': 2,
#  'Frederick': 2,
#  'Willard': 2,
#  'Media': 2,
#  'Newport': 2,
#  'Princeton': 2,
#  'Asbury': 2,
#  'Providence': 2,
#  'Euclid': 2,
#  'Darby': 2,
#  'Seneca': 2,
#  'Hackensack': 2,
#  'Carlisle': 2,
#  'Willoughby': 2,
#  'Brandon': 2,
#  'Carmichael': 2,
#  'Luxembourg': 2,
#  'Donegal': 2,
#  'Laos': 2,
#  'Parsons': 2,
#  'Tallulah': 2,
#  'Guthrie': 2,
#  'Bedford': 2,
#  'Parker': 2,
#  'Waycross': 2,
#  'Roanoke': 2,
#  'Violet': 2,
#  'Bowie': 2,
#  'Foley': 2,
#  'Ape': 2,
#  'Nuevo': 2,
#  'Canterbury': 2,
#  'Anaheim': 2,
#  'Dwight': 2,
#  'Wildwood': 2,
#  'Douglas': 2,
#  'Lucas': 2,
#  'Kota': 2,
#  'Jakarta': 2,
#  'Kingstown': 2,
#  'Rockaway': 2,
#  'Killarney': 2,
#  'Harrison': 2,
#  'Cameron': 2,
#  'Durango': 2,
#  'Porto': 2,
#  'Ashton': 2,
#  'Osaka': 2,
#  'Bong': 2,
#  'Morton': 2,
#  'Torquay': 2,
#  'Bradford': 2,
#  'Brisbane': 2,
#  'Lisbon': 2,
#  'Ukraine': 2,
#  'Garrett': 2,
#  'Sudbury': 2,
#  'Linden': 2,
#  'Cambodia': 2,
#  'Holden': 2,
#  'Petal': 2,
#  'Tecumseh': 2,
#  'Clayton': 2,
#  'Laurel': 2,
#  'Alamo': 2,
#  'Coolidge': 2,
#  'Grapevine': 2,
#  'Shoreline': 2,
#  'Minneapolis': 2,
#  'Highland': 2,
#  'Sheridan': 2,
#  'Raymond': 2,
#  'Fresno': 2,
#  'Hanoi': 2,
#  'Kerry': 2,
#  'Brea': 2,
#  'Hammond': 2,
#  'Montague': 2,
#  'Muli': 2,
#  'Stockholm': 2,
#  'Elsa': 2,
#  'Tacoma': 2,
#  'Macedon': 2,
#  'Grants': 2,
#  'Kimberly': 2,
#  'Blair': 2,
#  'Bowen': 2,
#  'Bradley': 2,
#  'Monument': 2,
#  'Saskatchewan': 2,
#  'Salisbury': 2,
#  'Dexter': 2,
#  'Chino': 2,
#  'Alpine': 2,
#  'Eastwood': 2,
#  'Madagascar': 2,
#  'Stirling': 2,
#  'Hawthorne': 2,
#  'Fairfax': 2,
#  'Konya': 2,
#  'Rupert': 2,
#  'Whitehouse': 2,
#  'Estonia': 2,
#  'Naval': 2,
#  'Biloxi': 2,
#  'Livingstone': 2,
#  'Crowley': 2,
#  'Hercules': 2,
#  'Melissa': 2,
#  'Wa': 2,
#  'Addison': 2,
#  'Salvador': 2,
#  'Cottonwood': 2,
#  'Aloha': 2,
#  'Scotia': 2,
#  'Seaside': 2,
#  'Bolivia': 2,
#  'Burton': 2,
#  'Hitchcock': 2,
#  'Joshua': 2,
#  'Kilmarnock': 2,
#  'Belize': 2,
#  'Casper': 2,
#  'Selma': 2,
#  'Thatcher': 2,
#  'Snyder': 2,
#  'Trinity': 2,
#  'Wigan': 1,
#  'Islington': 1,
#  'Fiji': 1,
#  'Mountainside': 1,
#  'Darwin': 1,
#  'Lamu': 1,
#  'Hibbing': 1,
#  'Acre': 1,
#  'Stockbridge': 1,
#  'Brownsville': 1,
#  'Lamas': 1,
#  'Magdalena': 1,
#  'Greenland': 1,
#  'Salinas': 1,
#  'Antioch': 1,
#  'Uri': 1,
#  'Bello': 1,
#  'Huntington': 1,
#  'Somers': 1,
#  'Jingling': 1,
#  'Theodore': 1,
#  'Ellington': 1,
#  'Colombia': 1,
#  'Rockville': 1,
#  'Timbuktu': 1,
#  'Nantucket': 1,
#  'Westmeath': 1,
#  'Melbourne': 1,
#  'Dorchester': 1,
#  'Agadir': 1,
#  'Ukiah': 1,
#  'Homeland': 1,
#  'Panda': 1,
#  'Ramsey': 1,
#  'Lenox': 1,
#  'Huntsville': 1,
#  'Toledo': 1,
#  'Stockton': 1,
#  'Willows': 1,
#  'Lac': 1,
#  'Coco': 1,
#  'Aragon': 1,
#  'Oceanside': 1,
#  'Overland': 1,
#  'Shiloh': 1,
#  'Georgetown': 1,
#  'Sofia': 1,
#  'Est': 1,
#  'Mullingar': 1,
#  'Delano': 1,
#  'Bam': 1,
#  'Banbridge': 1,
#  'Darlington': 1,
#  'Clare': 1,
#  'Armenia': 1,
#  'Edo': 1,
#  'Santiago': 1,
#  'Chandler': 1,
#  'Vallejo': 1,
#  'Chesterfield': 1,
#  'Parkland': 1,
#  'Kingsbury': 1,
#  'Camilla': 1,
#  'Peru': 1,
#  'Chanda': 1,
#  'Ulster': 1,
#  'Harper': 1,
#  'Sheboygan': 1,
#  'Katherine': 1,
#  'Wembley': 1,
#  'Coventry': 1,
#  'Frankfurt': 1,
#  'Beaumont': 1,
#  'Attawapiskat': 1,
#  'Sarnia': 1,
#  'Sussex': 1,
#  'Pace': 1,
#  'Para': 1,
#  'Istanbul': 1,
#  'Edinburgh': 1,
#  'Afghanistan': 1,
#  'Caracas': 1,
#  'Alliance': 1,
#  'Bologna': 1,
#  'Mango': 1,
#  'Tamiami': 1,
#  'Cortez': 1,
#  'Weston': 1,
#  'Grayson': 1,
#  'Sedona': 1,
#  'Seville': 1,
#  'Hearst': 1,
#  'Iceland': 1,
#  'Kilkenny': 1,
#  'Lyndon': 1,
#  'Sanford': 1,
#  'Nagasaki': 1,
#  'Toluca': 1,
#  'Joplin': 1,
#  'Selah': 1,
#  'Astoria': 1,
#  'Markham': 1,
#  'Cambridge': 1,
#  'Sterling': 1,
#  'Hereford': 1,
#  'Nottingham': 1,
#  'Gainesville': 1,
#  'Falun': 1,
#  'Yokohama': 1,
#  'Dubai': 1,
#  'Vermont': 1,
#  'Cincinnati': 1,
#  'Orillia': 1,
#  'Seymour': 1,
#  'Clive': 1,
#  'Tak': 1,
#  'Springhill': 1,
#  'Claiborne': 1,
#  'Sutton': 1,
#  'Bloke': 1,
#  'Porterville': 1,
#  'Pensacola': 1,
#  'Beatrice': 1,
#  'Tehran': 1,
#  'Boise': 1,
#  'Paraguay': 1,
#  'Cornwall': 1,
#  'Roswell': 1,
#  'Veracruz': 1,
#  'Oaxaca': 1,
#  'Hilton': 1,
#  'Hungary': 1,
#  'Allendale': 1,
#  'Lamont': 1,
#  'Singa': 1,
#  'Lubbock': 1,
#  'Frias': 1,
#  'Barrington': 1,
#  'Novato': 1,
#  'Fairport': 1,
#  'Blackfoot': 1,
#  'Aspen': 1,
#  'Progress': 1,
#  'Leavenworth': 1,
#  'Ellsworth': 1,
#  'Griffith': 1,
#  'Oran': 1,
#  'Milan': 1,
#  'Turbo': 1,
#  'Sunderland': 1,
#  'Webster': 1,
#  'Duarte': 1,
#  'Glendora': 1,
#  'Gaya': 1,
#  'Morgantown': 1,
#  'Wagoner': 1,
#  'Barranquilla': 1,
#  'Howell': 1,
#  'Tyrone': 1,
#  'Fowler': 1,
#  'Rothschild': 1,
#  'Edgewood': 1,
#  'Zanzibar': 1,
#  'Pueblo': 1,
#  'Meridian': 1,
#  'Indonesia': 1,
#  'Aruba': 1,
#  'Blackwell': 1,
#  'Lowell': 1,
#  'Finland': 1,
#  'Shu': 1,
#  'Addis': 1,
#  'Branson': 1,
#  'Bonita': 1,
#  'Breckenridge': 1,
#  'Peabody': 1,
#  'Avon': 1,
#  'Taza': 1,
#  'Iba': 1,
#  'Hartlepool': 1,
#  'Corona': 1,
#  'Kosovo': 1,
#  'Rosedale': 1,
#  'Maidstone': 1,
#  'Hayward': 1,
#  'Bixby': 1,
#  'Andrews': 1,
#  'LaBelle': 1,
#  'Rincon': 1,
#  'Kazakhstan': 1,
#  ...}

# %% [markdown]
# Above you can see that we have quite a few "names" and "places" in our lists that are actually just capitalized common words. We don't want to replace these, so below we take them out of our names lists as best we can.

# %%
names_to_keep = []
for name in names_in_data:
    if names_in_data[name] > 15:
        names_to_keep.append(name)

places_to_keep = ['Tea','Bow','Page','Grove','Eagle','Needles','Race','Friendly','Sandy','Center','Independence','Bell',\
                  'Sunrise','Bar','Bo','Western','Temple','Coast','Bear','Ho','Bright','Ocean','Central','Spring','Van',\
                  'Valley','Union','Nice','Northern','Holiday','Justice','Wall','Paradise','Sunset','Ba','Middle','Southern',\
                  'Welcome','Same','Golden','We','Man','King','Green','Star','Young','Mountain','Cadillac','Hope']

all_names = set(all_names) - set(names_to_keep)
all_places = set(all_places) - set(places_to_keep)

names_to_remove = all_names.union(all_places)

# %% [markdown]
# Now let's actually perform the replacement.

# %%
new_lyrics = []
new_titles = []
for index, record in dataset.iterrows():
    title = record['song']
    lyrics = record['text']
    for name in names_to_remove:
        title = title.replace(name,'____')
        lyrics = lyrics.replace(name,'____')
    new_titles.append(title)
    new_lyrics.append(lyrics)

# %%
dataset['song'] = new_titles
dataset['text'] = new_lyrics

# %%
dataset.drop('int_text', axis = 1)

# %% [markdown]
# #### Reduce Lyrics to Lowercase
#
# Last abnormality we are going to remove from our song lyrics is capitalization. Ideally, we would like our model to understand the meaning of capitalized words and their use, but once again we are going for simplicity. For the most part, our capitalized words are just the first word of each line. This is really just a format and we could understand the lyrics just as well if the words were lowercase. So instead of hoping that our model catches onto this pattern, we will just make everything lowercase. This also has the added benefit of reducing the vocabulary space for our model, since it now does not have to differentiate between a word and its capitalized version. The only downside to doing this is that it might affect proper nouns and our models use of them. We think these are too far and in-between to make a significant impact. We may have to address this if it becomes an issue though.
#
# Below we make the artist, song title, and song lyrics all lowercase.

# %%
# reduce tect in each column of dataset to lowercase
dataset['artist'] = dataset['artist'].str.lower()
dataset['song'] = dataset['song'].str.lower()
dataset['text'] = dataset['text'].str.lower()

# %%
dataset
# Out:
#              artist                   song  \
# 0              abba  she's my kind of girl
# 1              abba       andante, andante
# 2              abba         as good as new
# 3              abba                   bang
# 4              abba       bang-a-boomerang
# ...             ...                    ...
# 57644  ziggy marley             generation
# 57645  ziggy marley          good old days
# 57647          zwan           come with me
# 57648          zwan                 desire
# 57649          zwan              heartsong
#
#                                                     text
# 0      look at her face, it's a wonderful face\nand i...
# 1      take it easy with me, please\ntouch me gently ...
# 2      i'll never know why i had to go\nwhy i had to ...
# 3      making somebody happy is a question of give an...
# 4      making somebody happy is a question of give an...
# ...                                                  ...
# 57644  many generation have passed away\nfighting for...
# 57645  irie days come on play\nlet the angels fly let...
# 57647  all you need\nis something i'll believe\nflash...
# 57648  northern star\nam i frightened\nwhere can i go...
# 57649  come in\nmake yourself at home\ni'm a bit late...
#
# [47973 rows x 3 columns]

# %% [markdown]
# Now that we have removed all the unwanted qualities, characters, and structures in our song lyrics, we will try adding a few to make training our model more effective. Below are some of the changes and additions we are going to make:
#
#     1) Punctuation: Make punctuation characters their own words
#     2) Line Indicators: Add special characters to indicate start and end of each lyrical line
#     3) Artist and Song Title: Add artist name and song title to front of each song text, wrapped with indicators
#     4) Song End and Start: Add indicators for the start and end of each song
#
# By adding these patterns and indicators into our song lyrics we hope to make it easier for our model to learn what a line is, how to start and end a song, specific patterns for certain artists, and relationships between the song title and the lyrics of the song.
#
# #### Punctuation
#
# First, we are going to separate punctuation within our song lyrics so that any of the following characters {",:;.!?} are treated as their own word. Our reasoning behind this is two fold. Firstly, each of these characters carries their own special meaning seperate from the word they are attached to. In act the fact they are attached to a word is just a formatting convention. Because of this it makes sense to treat them as separate elements that our model needs to learn how to use properly. Secondly, separating these characters from the words they are attached to significantly reduces our vocabulary space. If ever possible combination of word and punctuation existed, then our sample space would be 7 times as large.
#
# Below we wrote a function that pads any occurrence of these characters with spaces on each side. It then removes all occurrences of multiple spaces in case we created any.

# %%
# define function that pads characters {",:;.!?} with spaces so they are treated like separate words
def CharPadder(data, characters):
    # Iterate over characters and pad
    for c in characters:
        data['text'] = data['text'].str.replace(c, ' '+c+' ')
    # remove occurences of multiple spaces
    data['text'] = data['text'].str.replace(' +', ' ')
    
    return data
    
# define characters to pad
characters = '",:;.!?'

# pad characters in dataset
dataset = CharPadder(dataset.copy(), characters)

# %% [markdown]
# #### Adding Line Indicators
#
# Next let's add the line indicators to the beginning and end of each line in our text. It doesn't really matter what we use for the indicators so long as they don't already exist in our dataset. They should probably also be more descriptive as well, but I'm not that creative and want to make sure they stand out, so we are going to be using "xxx110" and "xxx111" for the start and end of each line respectively. These look pretty dumb, but actually follow a pattern similar to the indicators that will be used for the song, title, and artist. Below we actually check to make sure these indicators don't exist in the dataset already, as well as the indicators we will use later.

# %%
# grabbing unique words from artist, title, and text for each record
unique_words = set()
for index, record in dataset.iterrows():
    artist_words = set(record['artist'].split(' '))
    title_words = set(record['song'].split(' '))
    text_words = set(record['text'].split(' '))
    unique_words = unique_words.union(artist_words, title_words, text_words)

# Indicators we will be using for start/end of song, artist, title, line
indicators_dict = {'start_song': 'xxx000', 'start_artist': 'xxx010', 'start_title': 'xxx100', 'start_line': 'xxx110', 
                    'end_song': 'xxx001',   'end_artist': 'xxx011',   'end_title': 'xxx101',   'end_line': 'xxx111'}

passes = 0
for key in indicators_dict:
    indicator = indicators_dict[key]
    if indicator in unique_words:
        print('Fail: {} indicator, "{}", found in dataset vocabulary.'.format(key, indicator))
    else:
        print('Pass: {} indicator, "{}", distinct from dataset vocabulary.'.format(key, indicator))
        passes += 1
        
if passes == len(indicators_dict):
    print("Success!!! All indicators are unique and valid.")
else:
    print("NOOOOO!!! Some of the indicators are not valid and must be replaced.")
# Out:
# Pass: start_song indicator, "xxx000", distinct from dataset vocabulary.
# Pass: start_artist indicator, "xxx010", distinct from dataset vocabulary.
# Pass: start_title indicator, "xxx100", distinct from dataset vocabulary.
# Pass: start_line indicator, "xxx110", distinct from dataset vocabulary.
# Pass: end_song indicator, "xxx001", distinct from dataset vocabulary.
# Pass: end_artist indicator, "xxx011", distinct from dataset vocabulary.
# Pass: end_title indicator, "xxx101", distinct from dataset vocabulary.
# Pass: end_line indicator, "xxx111", distinct from dataset vocabulary.
# Success!!! All indicators are unique and valid.

# %% [markdown]
# Now that we know our indicators are unique, let's make a function that adds the line indicators to our song text. This will be easy since the character '\n' indicates the end of each line and the start of the next. We probably should remove the new line character, '\n', during the replacement, but for now we will leave them in to make it easier to look at the results.

# %%
# function that adds line indicators to song text
def IndicateLines(data, start, end):
    # initiate list for new text
    new_text = []
    for index, record in data.iterrows():
        text = record['text']
        # strip leading and trailing whitespace
        text = text.lstrip().rstrip()
        # add indicators at each new line
        pattern = ' '+end+'\n'+start+' '
        text = text.replace('\n', pattern)
        # add indicators to beginning and end of song
        text = start+' '+text
        text = text+' '+end
        # append to list
        new_text.append(text)
    
    # replace txt
    data['text'] = new_text
    
    # remove occurences of multiple spaces
    data['text'] = data['text'].str.replace(' +', ' ')
    
    return data

# run function on dataset
start = indicators_dict['start_line']
end = indicators_dict['end_line']
dataset = IndicateLines(dataset.copy(), start, end)

# Display example
example_1 = dataset.loc[1]
print('Artist: ' + example_1['artist'])
print('Title: ' + example_1['song'])
print(example_1['text'])
# Out:
# Artist: abba
# Title: andante, andante
# xxx110 take it easy with me , please xxx111
# xxx110 touch me gently like a summer evening breeze xxx111
# xxx110 take your time , make it slow xxx111
# xxx110 andante , andante xxx111
# xxx110 just let the feeling grow xxx111
# xxx110 make your fingers soft and light xxx111
# xxx110 let your body be the velvet of the night xxx111
# xxx110 touch my soul , you know how xxx111
# xxx110 andante , andante xxx111
# xxx110 go slowly with me now xxx111
# xxx110 i'm your music xxx111
# xxx110 i'm your song xxx111
# xxx110 play me time and time again and make me strong xxx111
# xxx110 make me sing , make me sound xxx111
# xxx110 andante , andante xxx111
# xxx110 tread lightly on my ground xxx111
# xxx110 andante , andante xxx111
# xxx110 oh please don't let me down xxx111
# xxx110 there's a shimmer in your eyes xxx111
# xxx110 like the feeling of a thousand butterflies xxx111
# xxx110 please don't talk , go on , play xxx111
# xxx110 andante , andante xxx111
# xxx110 and let me float away xxx111
# xxx110 i'm your music xxx111
# xxx110 i'm your song xxx111
# xxx110 play me time and time again and make me strong xxx111
# xxx110 make me sing , make me sound xxx111
# xxx110 andante , andante xxx111
# xxx110 tread lightly on my ground xxx111
# xxx110 andante , andante xxx111
# xxx110 oh please don't let me down xxx111
# xxx110 make me sing , make me sound xxx111
# xxx110 andante , andante xxx111
# xxx110 tread lightly on my ground xxx111
# xxx110 andante , andante xxx111
# xxx110 oh please don't let me down xxx111
# xxx110 andante , andante xxx111
# xxx110 oh please don't let me down xxx111

# %% [markdown]
# #### Adding Artist and Song Title
#
# Next we are going to add the name of the artist and the title of the song to the front of each song's lyrics. Each will be wrapped in indicators that specify when the artist/title begins and ends. We hope that by adding these two features into the lyrics our models can learn to identify certain lyrical themes and patterns for each artist and learn relationships between the name of the song and the lyrics of the song. For instance, typically the title of the song appears within its lyrics, usually repeated multiple times in the chorus. This is the type of pattern we would like our model to pick up on.
#
# Below we wrote a function that adds both the artist and title of the song to the front of the lyrics in that order. We then apply it to the dataset and then display an exampl of the results.

# %%
# function that adds line indicators to song text
def AddArtistTitle(data, artist_start, artist_end, title_start, title_end):
    # initiate list for new text
    new_text = []
    for index, record in data.iterrows():
        text = record['text'].lstrip().rstrip()
        artist = record['artist'].lstrip().rstrip()
        title = record['song'].lstrip().rstrip()
        # add title
        title_line = title_start+' '+title+' '+title_end+'\n'
        text = title_line + text
        # add artist
        artist_line = artist_start+' '+artist+' '+artist_end+'\n'
        text = artist_line + text
        # append to list
        new_text.append(text)
    
    # replace txt
    data['text'] = new_text
    
    # remove occurences of multiple spaces
    data['text'] = data['text'].str.replace(' +', ' ')
    
    return data

# run function on dataset
artist_start = indicators_dict['start_artist']
artist_end = indicators_dict['end_artist']
title_start = indicators_dict['start_title']
title_end = indicators_dict['end_title']
dataset = AddArtistTitle(dataset.copy(), artist_start, artist_end, title_start, title_end)

# Display example
example_1 = dataset.loc[1]
print('Artist: ' + example_1['artist'])
print('Title: ' + example_1['song'])
print(example_1['text'])
# Out:
# Artist: abba
# Title: andante, andante
# xxx010 abba xxx011
# xxx100 andante, andante xxx101
# xxx110 take it easy with me , please xxx111
# xxx110 touch me gently like a summer evening breeze xxx111
# xxx110 take your time , make it slow xxx111
# xxx110 andante , andante xxx111
# xxx110 just let the feeling grow xxx111
# xxx110 make your fingers soft and light xxx111
# xxx110 let your body be the velvet of the night xxx111
# xxx110 touch my soul , you know how xxx111
# xxx110 andante , andante xxx111
# xxx110 go slowly with me now xxx111
# xxx110 i'm your music xxx111
# xxx110 i'm your song xxx111
# xxx110 play me time and time again and make me strong xxx111
# xxx110 make me sing , make me sound xxx111
# xxx110 andante , andante xxx111
# xxx110 tread lightly on my ground xxx111
# xxx110 andante , andante xxx111
# xxx110 oh please don't let me down xxx111
# xxx110 there's a shimmer in your eyes xxx111
# xxx110 like the feeling of a thousand butterflies xxx111
# xxx110 please don't talk , go on , play xxx111
# xxx110 andante , andante xxx111
# xxx110 and let me float away xxx111
# xxx110 i'm your music xxx111
# xxx110 i'm your song xxx111
# xxx110 play me time and time again and make me strong xxx111
# xxx110 make me sing , make me sound xxx111
# xxx110 andante , andante xxx111
# xxx110 tread lightly on my ground xxx111
# xxx110 andante , andante xxx111
# xxx110 oh please don't let me down xxx111
# xxx110 make me sing , make me sound xxx111
# xxx110 andante , andante xxx111
# xxx110 tread lightly on my ground xxx111
# xxx110 andante , andante xxx111
# xxx110 oh please don't let me down xxx111
# xxx110 andante , andante xxx111
# xxx110 oh please don't let me down xxx111

# %% [markdown]
# #### Adding Start/End Song Indicators
#
# Lastly, we are going to add indicators which specify the beginning and end of each song's lyrics. One might think this isn't necessary since all our songs are separated. However, depending on the type of model we are training, we may combine the songs into a single string from which we pull segments for training examples. Furthermore, making the start and end of our songs well defined should help our model learn how to indicate the start/end of a song. This will be especially useful during song generation.
#
# Below we wrote a function to add the indicators to the start and end of each song. Then we run the function on our dataset and display an example of the results.

# %%
# function that adds line indicators to song text
def IndicateSong(data, start, end):
    # initiate list for new text
    new_text = []
    for index, record in data.iterrows():
        text = record['text'].lstrip().rstrip()
        # add start
        text = start + '\n' + text
        # add end
        text = text + '\n' + end
        # append to list
        new_text.append(text)
    
    # replace txt
    data['text'] = new_text
    
    # remove occurences of multiple spaces
    data['text'] = data['text'].str.replace(' +', ' ')
    
    return data

# run function on dataset
start = indicators_dict['start_song']
end = indicators_dict['end_song']
dataset = IndicateSong(dataset.copy(), start, end)

# Display example
example_1 = dataset.loc[1]
print('Artist: ' + example_1['artist'])
print('Title: ' + example_1['song'])
print(example_1['text'])
# Out:
# Artist: abba
# Title: andante, andante
# xxx000
# xxx010 abba xxx011
# xxx100 andante, andante xxx101
# xxx110 take it easy with me , please xxx111
# xxx110 touch me gently like a summer evening breeze xxx111
# xxx110 take your time , make it slow xxx111
# xxx110 andante , andante xxx111
# xxx110 just let the feeling grow xxx111
# xxx110 make your fingers soft and light xxx111
# xxx110 let your body be the velvet of the night xxx111
# xxx110 touch my soul , you know how xxx111
# xxx110 andante , andante xxx111
# xxx110 go slowly with me now xxx111
# xxx110 i'm your music xxx111
# xxx110 i'm your song xxx111
# xxx110 play me time and time again and make me strong xxx111
# xxx110 make me sing , make me sound xxx111
# xxx110 andante , andante xxx111
# xxx110 tread lightly on my ground xxx111
# xxx110 andante , andante xxx111
# xxx110 oh please don't let me down xxx111
# xxx110 there's a shimmer in your eyes xxx111
# xxx110 like the feeling of a thousand butterflies xxx111
# xxx110 please don't talk , go on , play xxx111
# xxx110 andante , andante xxx111
# xxx110 and let me float away xxx111
# xxx110 i'm your music xxx111
# xxx110 i'm your song xxx111
# xxx110 play me time and time again and make me strong xxx111
# xxx110 make me sing , make me sound xxx111
# xxx110 andante , andante xxx111
# xxx110 tread lightly on my ground xxx111
# xxx110 andante , andante xxx111
# xxx110 oh please don't let me down xxx111
# xxx110 make me sing , make me sound xxx111
# xxx110 andante , andante xxx111
# xxx110 tread lightly on my ground xxx111
# xxx110 andante , andante xxx111
# xxx110 oh please don't let me down xxx111
# xxx110 andante , andante xxx111
# xxx110 oh please don't let me down xxx111
# xxx001

# %% [markdown]
# And now that we have the text formatted the way we want, we can remove the newline characters. We only included them up to this point to visualy make it easier to inspect the results of our transformations. Having completed these alterations, we will remove the newlines so the lyrics are a sequence of words.

# %%
# replaceing newline characters with spaces
dataset['text'] = dataset['text'].str.replace('\n', ' ')

# display example result
example_1 = dataset.loc[1]
print('Artist: ' + example_1['artist'])
print('Title: ' + example_1['song'])
print(example_1['text'])
# Out:
# Artist: abba
# Title: andante, andante
# xxx000 xxx010 abba xxx011 xxx100 andante, andante xxx101 xxx110 take it easy with me , please xxx111 xxx110 touch me gently like a summer evening breeze xxx111 xxx110 take your time , make it slow xxx111 xxx110 andante , andante xxx111 xxx110 just let the feeling grow xxx111 xxx110 make your fingers soft and light xxx111 xxx110 let your body be the velvet of the night xxx111 xxx110 touch my soul , you know how xxx111 xxx110 andante , andante xxx111 xxx110 go slowly with me now xxx111 xxx110 i'm your music xxx111 xxx110 i'm your song xxx111 xxx110 play me time and time again and make me strong xxx111 xxx110 make me sing , make me sound xxx111 xxx110 andante , andante xxx111 xxx110 tread lightly on my ground xxx111 xxx110 andante , andante xxx111 xxx110 oh please don't let me down xxx111 xxx110 there's a shimmer in your eyes xxx111 xxx110 like the feeling of a thousand butterflies xxx111 xxx110 please don't talk , go on , play xxx111 xxx110 andante , andante xxx111 xxx110 and let me float away xxx111 xxx110 i'm your music xxx111 xxx110 i'm your song xxx111 xxx110 play me time and time again and make me strong xxx111 xxx110 make me sing , make me sound xxx111 xxx110 andante , andante xxx111 xxx110 tread lightly on my ground xxx111 xxx110 andante , andante xxx111 xxx110 oh please don't let me down xxx111 xxx110 make me sing , make me sound xxx111 xxx110 andante , andante xxx111 xxx110 tread lightly on my ground xxx111 xxx110 andante , andante xxx111 xxx110 oh please don't let me down xxx111 xxx110 andante , andante xxx111 xxx110 oh please don't let me down xxx111 xxx001

# %% [markdown]
# Looking at the above example, we just realized that special characters were not removed or padded from the artist and title. As such, they could exist in the new lyrics now that we appended the artist name and song title to the front of the lyrics. Let's remedy this mistake by removing the unwanted characters and padding our special characters one more time. After doing so we display an example of the results.

# %%
# define characters to remove
unwanted_char = string.punctuation.replace('"','').replace("'",'').replace('.','').replace('?','').replace('!','')\
                .replace(',','').replace(':','').replace(';','').replace('-','')
pattern = '[\\/'+unwanted_char+']'

# remove unwanted characters
dataset['text'] = dataset['text'].str.replace(pattern,'')

# define characters to pad
characters = '",:;.!?'

# pad characters in dataset
dataset = CharPadder(dataset.copy(), characters)

# display example result
example_1 = dataset.loc[1]
print('Artist: ' + example_1['artist'])
print('Title: ' + example_1['song'])
print(example_1['text'])
# Out:
# Artist: abba
# Title: andante, andante
# xxx000 xxx010 abba xxx011 xxx100 andante , andante xxx101 xxx110 take it easy with me , please xxx111 xxx110 touch me gently like a summer evening breeze xxx111 xxx110 take your time , make it slow xxx111 xxx110 andante , andante xxx111 xxx110 just let the feeling grow xxx111 xxx110 make your fingers soft and light xxx111 xxx110 let your body be the velvet of the night xxx111 xxx110 touch my soul , you know how xxx111 xxx110 andante , andante xxx111 xxx110 go slowly with me now xxx111 xxx110 i'm your music xxx111 xxx110 i'm your song xxx111 xxx110 play me time and time again and make me strong xxx111 xxx110 make me sing , make me sound xxx111 xxx110 andante , andante xxx111 xxx110 tread lightly on my ground xxx111 xxx110 andante , andante xxx111 xxx110 oh please don't let me down xxx111 xxx110 there's a shimmer in your eyes xxx111 xxx110 like the feeling of a thousand butterflies xxx111 xxx110 please don't talk , go on , play xxx111 xxx110 andante , andante xxx111 xxx110 and let me float away xxx111 xxx110 i'm your music xxx111 xxx110 i'm your song xxx111 xxx110 play me time and time again and make me strong xxx111 xxx110 make me sing , make me sound xxx111 xxx110 andante , andante xxx111 xxx110 tread lightly on my ground xxx111 xxx110 andante , andante xxx111 xxx110 oh please don't let me down xxx111 xxx110 make me sing , make me sound xxx111 xxx110 andante , andante xxx111 xxx110 tread lightly on my ground xxx111 xxx110 andante , andante xxx111 xxx110 oh please don't let me down xxx111 xxx110 andante , andante xxx111 xxx110 oh please don't let me down xxx111 xxx001

# %% [markdown]
# ## Formatting Data For Models
#
# Now that we have cleansed our data and normalized the text properly, it is time to structure the data in a format that can be used by the models we expect to train. To get our data in this format we will perform the following tasks:
#
#     1) Vectorize Data: tranform our song lyrics from a sequence of words to a sequence of integer representations
#     2) Combine Songs: final reformatting of data combining all songs into a single array

# %% [markdown]
# ### 1) Vectorize Data
#
# As far as I know there is no way to train Tensorflow models using non-numerical inputs. Therefore, we will be transforming our textual song lyrics to numerical representations. To do so, we will convert our lyrics from a sequence of words to a sequence of integers. Below we wrote a function that performs this vectorization. The function returns a new dataframe with the vectorized text in a new column, as well as a dictionary used to map from text -> integers and the inverse mapping from integers -> text. After making the function we then use it to vectorize the dataset and display an example of the integer representation of a songs.

# %%
# defining function for vectorizing textual data
def Vectorizer(data):
    # Find unique words
    unique_words = set()
    for index, record in dataset.iterrows():
        words = set(record['text'].split(' '))
        unique_words = unique_words.union(words)
    unique_words = sorted(unique_words)
    
    # Create transformation mappings
    text2int = {word:i for i, word in enumerate(unique_words)}
    int2text = np.array(unique_words)
    
    # Initiate list for vectorized text
    int_text = []
    for index, record in dataset.iterrows():
        text = record['text'].split(' ')
        vectorized_text = []
        for word in text:
            vectorized_text.append(text2int[word])
        int_text.append(vectorized_text)
        
    data['int_text'] = int_text
    
    return data, text2int, int2text

# %%
# vectorize dataset
dataset, text2int, int2text = Vectorizer(dataset.copy())

# %%
# Display mappings
print('Dimensionality of Word Space: {}\n'.format(len(text2int)))

# Display example vectorized song and devectorized song
example_1 = dataset.loc[1]
print('Example Song\n------------')
print('Artist: ' + example_1['artist'])
print('Title: ' + example_1['song'])
print('Vectorized Song')
print(example_1['int_text'])
print('De-vectorized Text')
print(' '.join(int2text[example_1['int_text']]))
# Out:
# Dimensionality of Word Space: 92447
#
# Example Song
# ------------
# Artist: abba
# Title: andante, andante
# Vectorized Song
# [91159, 91161, 2848, 91162, 91163, 5090, 1054, 5090, 91164, 91165, 80025, 42094, 25970, 90248, 51010, 1054, 62371, 91166, 91165, 83107, 51010, 33174, 47316, 2032, 78669, 27750, 12126, 91166, 91165, 80025, 91976, 82266, 1054, 49661, 42094, 74629, 91166, 91165, 5090, 1054, 5090, 91166, 91165, 43575, 46864, 81371, 29351, 35198, 91166, 91165, 49661, 91976, 29965, 75288, 5070, 47239, 91166, 91165, 46864, 91976, 11070, 8666, 81371, 86939, 57453, 81371, 56003, 91166, 91165, 83107, 54494, 75762, 1054, 91855, 44921, 39260, 91166, 91165, 5090, 1054, 5090, 91166, 91165, 34005, 74647, 90248, 51010, 56804, 91166, 91165, 39850, 91976, 54334, 91166, 91165, 39850, 91976, 75563, 91166, 91165, 62299, 51010, 82266, 5070, 82266, 3741, 5070, 49661, 51010, 78062, 91166, 91165, 49661, 51010, 73760, 1054, 49661, 51010, 75798, 91166, 91165, 5090, 1054, 5090, 91166, 91165, 83601, 47276, 57929, 54494, 35167, 91166, 91165, 5090, 1054, 5090, 91166, 91165, 57554, 62371, 24332, 46864, 51010, 24733, 91166, 91165, 81471, 2032, 72734, 40643, 91976, 28445, 91166, 91165, 47316, 81371, 29351, 57453, 2032, 81773, 13255, 91166, 91165, 62371, 24332, 80094, 1054, 34005, 57929, 1054, 62299, 91166, 91165, 5090, 1054, 5090, 91166, 91165, 5070, 46864, 51010, 30562, 6992, 91166, 91165, 39850, 91976, 54334, 91166, 91165, 39850, 91976, 75563, 91166, 91165, 62299, 51010, 82266, 5070, 82266, 3741, 5070, 49661, 51010, 78062, 91166, 91165, 49661, 51010, 73760, 1054, 49661, 51010, 75798, 91166, 91165, 5090, 1054, 5090, 91166, 91165, 83601, 47276, 57929, 54494, 35167, 91166, 91165, 5090, 1054, 5090, 91166, 91165, 57554, 62371, 24332, 46864, 51010, 24733, 91166, 91165, 49661, 51010, 73760, 1054, 49661, 51010, 75798, 91166, 91165, 5090, 1054, 5090, 91166, 91165, 83601, 47276, 57929, 54494, 35167, 91166, 91165, 5090, 1054, 5090, 91166, 91165, 57554, 62371, 24332, 46864, 51010, 24733, 91166, 91165, 5090, 1054, 5090, 91166, 91165, 57554, 62371, 24332, 46864, 51010, 24733, 91166, 91160]
# De-vectorized Text
# xxx000 xxx010 abba xxx011 xxx100 andante , andante xxx101 xxx110 take it easy with me , please xxx111 xxx110 touch me gently like a summer evening breeze xxx111 xxx110 take your time , make it slow xxx111 xxx110 andante , andante xxx111 xxx110 just let the feeling grow xxx111 xxx110 make your fingers soft and light xxx111 xxx110 let your body be the velvet of the night xxx111 xxx110 touch my soul , you know how xxx111 xxx110 andante , andante xxx111 xxx110 go slowly with me now xxx111 xxx110 i'm your music xxx111 xxx110 i'm your song xxx111 xxx110 play me time and time again and make me strong xxx111 xxx110 make me sing , make me sound xxx111 xxx110 andante , andante xxx111 xxx110 tread lightly on my ground xxx111 xxx110 andante , andante xxx111 xxx110 oh please don't let me down xxx111 xxx110 there's a shimmer in your eyes xxx111 xxx110 like the feeling of a thousand butterflies xxx111 xxx110 please don't talk , go on , play xxx111 xxx110 andante , andante xxx111 xxx110 and let me float away xxx111 xxx110 i'm your music xxx111 xxx110 i'm your song xxx111 xxx110 play me time and time again and make me strong xxx111 xxx110 make me sing , make me sound xxx111 xxx110 andante , andante xxx111 xxx110 tread lightly on my ground xxx111 xxx110 andante , andante xxx111 xxx110 oh please don't let me down xxx111 xxx110 make me sing , make me sound xxx111 xxx110 andante , andante xxx111 xxx110 tread lightly on my ground xxx111 xxx110 andante , andante xxx111 xxx110 oh please don't let me down xxx111 xxx110 andante , andante xxx111 xxx110 oh please don't let me down xxx111 xxx001

# %% [markdown]
# ### 2) Reformat Dataset
#
# The last transformation we need to do to our dataset is reformat it as a single array. This is a conveniant format that we can save in a json file and then reload later when training our models. In doing so, we are also going to create several versions of our datasets and for each we will create a training set as well as a validation set. We need multiple types of datasets because the various models we will train take different inputs. Primarily, some of the models will take variable length seqeunces for which we will combine all the songs into a single sequence, and the other models will train on each individual song. Additionally, we are going to separate out just the Steely Dan songs into their own set since we fill fine tune our models using just these songs. Below is a description of the 4 datasets we will create:
#
#     1) All Songs, Single Sequence: All the songs combined into a single sequence (includes Steely Dan songs)
#     2) Steely Dan Songs, Single Sequence: Steely Dan songs combined into a single sequence
#     3) All Songs Separated: All songs combined into a single list as separate entries (includes Steely Dan songs)
#     4) Steely Dan Songs Separated: Steely Dan songs combined into a single
#
# For each of these datasets we will have both a training set and a validation set. The validation and training songs will be randomly chosen, but will be the same between the sets, so the single sequence set has the same songs as the separated sequences set. We will partition 10% of the set for validation.

# %% [markdown]
# #### Separate Steely Dan Songs
#
# First let's find our Steely Dan songs. Below we filter out these songs into their own dataset.

# %%
# Filter to Steely Dan songs
SD_dataset = dataset[dataset['artist']=='steely dan']

# display dataset
SD_dataset
# Out:
#            artist                   song  \
# 18783  steely dan              barrytown
# 18784  steely dan              black cow
# 18785  steely dan          book of liars
# 18786  steely dan      brain tap shuffle
# 18787  steely dan               brooklyn
# ...           ...                    ...
# 52188  steely dan     two against nature
# 52190  steely dan  what a shame about me
# 52191  steely dan             with a gun
# 52192  steely dan        your gold teeth
# 52193  steely dan     your gold teeth ii
#
#                                                     text  \
# 18783  xxx000 xxx010 steely dan xxx011 xxx100 barryto...
# 18784  xxx000 xxx010 steely dan xxx011 xxx100 black c...
# 18785  xxx000 xxx010 steely dan xxx011 xxx100 book of...
# 18786  xxx000 xxx010 steely dan xxx011 xxx100 brain t...
# 18787  xxx000 xxx010 steely dan xxx011 xxx100 brookly...
# ...                                                  ...
# 52188  xxx000 xxx010 steely dan xxx011 xxx100 two aga...
# 52190  xxx000 xxx010 steely dan xxx011 xxx100 what a ...
# 52191  xxx000 xxx010 steely dan xxx011 xxx100 with a ...
# 52192  xxx000 xxx010 steely dan xxx011 xxx100 your go...
# 52193  xxx000 xxx010 steely dan xxx011 xxx100 your go...
#
#                                                 int_text
# 18783  [91159, 91161, 77260, 20937, 91162, 91163, 836...
# 18784  [91159, 91161, 77260, 20937, 91162, 91163, 103...
# 18785  [91159, 91161, 77260, 20937, 91162, 91163, 113...
# 18786  [91159, 91161, 77260, 20937, 91162, 91163, 118...
# 18787  [91159, 91161, 77260, 20937, 91162, 91163, 124...
# ...                                                  ...
# 52188  [91159, 91161, 77260, 20937, 91162, 91163, 847...
# 52190  [91159, 91161, 77260, 20937, 91162, 91163, 892...
# 52191  [91159, 91161, 77260, 20937, 91162, 91163, 902...
# 52192  [91159, 91161, 77260, 20937, 91162, 91163, 919...
# 52193  [91159, 91161, 77260, 20937, 91162, 91163, 919...
#
# [81 rows x 4 columns]

# %% [markdown]
# #### Training and Validation
#
# Now that we separated out our Steely Dan songs, lets break each dataset into a training and validation dataset. As mentioned before, we will randomly choose which songs are in each dataset, and will allocate 10% of the total set for validation. Below we wrote a function to perform this operation.

# %%
import numpy as np

# function that partitions dataset into training and validation
def TVPartition(data, val_ratio):
    N = len(data)
    n = int(np.floor(N*val_ratio))
    random_indx = np.random.choice(N, n, replace = False)
    val_indx = data.iloc[random_indx].index
    validation_dataset = data.loc[val_indx]
    training_dataset = data.drop(val_indx)
    
    return training_dataset, validation_dataset

# %%
val_ratio = .1

# split up full dataset
training_dataset , validation_dataset = TVPartition(dataset.copy(), val_ratio)

# split up Steely Dan dataset
SD_training_dataset , SD_validation_dataset = TVPartition(SD_dataset.copy(), val_ratio)

# %% [markdown]
# #### Reformat As List
#
# With our datasets separated out into validation and training subsets, we can now move on to our final step, reformatting the dataframes into lists. We want to reformat our data into a list because it will let us easily save the transformed data into a json file and easily allow us to reload the data later into a numpy array. After transforming the records into a list of records, we will also create our secondary datasets, where all the songs are combined into  single sequence, by concatenating all the lists together. Below we wrote a function to extract the records into a list from a dataframe, and a function to combine the entries of thes lists into a single depth list.

# %%
# function to extract records from dataframe into list
def DF2List(data, column_name):
    return list(data[column_name])

# function to convert list of list to single depth list (one sequence)
def SingleSequence(list_data):
    # initiate new list
    new_list = []
    # add each list in list_data to new list
    for data in list_data:
        new_list += data
        
    return new_list

# %%
# tranform our dataframes to list
column_name = 'int_text'

# First set of data (all songs separate list per song)
training_1 = DF2List(training_dataset, column_name)
validation_1 = DF2List(validation_dataset, column_name)

# Second set of data (Steely Dan songs separt list per song)
training_2 = DF2List(SD_training_dataset, column_name)
validation_2 = DF2List(SD_validation_dataset, column_name)

# Third set of data (all songs single list/sequence)
training_3 = SingleSequence(training_1)
validation_3 = SingleSequence(validation_1)

# Fourth set of data (Steely Dan songs single list/sequence)
training_4 = SingleSequence(training_2)
validation_4 = SingleSequence(validation_2)

# %% [markdown]
# ## Saving Data
#
# After cleansing, transforming, and reformatting our data, it is now finally time to save the resultant datasets so that we don't have to go trhough this process again. We have decided to save each dataset, validation and training, into a separate file along with the vectorizing maps, text2int and int2text. We will be save thes as JSON files. Below we wrote a function to perform these actions.

# %%
import json

# function for saving dataset to json file
def SaveData(filename, training_dataset, validation_dataset, int2text):
    print('Saving datasets and mapping to filename: '+filename)
    # Build data dictionary that will be saved
    data = {'training_dataset': training_dataset,
            'validation_dataset': validation_dataset,
            'unique_values': int2text.tolist()}
    # Write to savefile
    with open(filename, 'w') as f:
        json.dump(data, f)
    print('Saving datasets complete')

# %%
# Save each dataset to separate file
filename_1 = 'all_song_lyrics_1.json'
filename_2 = 'SD_song_lyrics_1.json'
filename_3 = 'all_song_lyrics_2.json'
filename_4 = 'SD_song_lyrics_2.json'

SaveData(filename_1, training_1, validation_1, int2text)
SaveData(filename_2, training_2, validation_2, int2text)
SaveData(filename_3, training_3, validation_3, int2text)
SaveData(filename_4, training_4, validation_4, int2text)
# Out:
# Saving datasets and mapping to filename: all_song_lyrics_1.json
# Saving datasets complete
# Saving datasets and mapping to filename: SD_song_lyrics_1.json
# Saving datasets complete
# Saving datasets and mapping to filename: all_song_lyrics_2.json
# Saving datasets complete
# Saving datasets and mapping to filename: SD_song_lyrics_2.json
# Saving datasets complete
